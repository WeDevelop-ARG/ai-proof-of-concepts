# %% [markdown]
# # **Mounting google drive file system**

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# !pip install keras==2.2.5
# !pip install tensorflow-gpu==1.15.2
# Out:
# Requirement already satisfied: keras==2.2.5 in /usr/local/lib/python3.6/dist-packages (2.2.5)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.5) (1.1.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.5) (1.4.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.5) (1.12.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras==2.2.5) (3.13)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.5) (1.0.8)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.5) (1.18.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras==2.2.5) (2.10.0)
# Requirement already satisfied: tensorflow-gpu==1.15.2 in /usr/local/lib/python3.6/dist-packages (1.15.2)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.2) (0.8.1)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.2) (3.10.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.2) (0.9.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.2) (1.12.1)
# Requirement already satisfied: gast==0.2.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.2) (0.2.2)
# Requirement already satisfied: tensorflow-estimator==1.15.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.2) (1.15.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.2) (1.12.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.2) (3.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.2) (1.1.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.2) (1.1.0)
# Requirement already satisfied: tensorboard<1.16.0,>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.2) (1.15.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.2) (1.27.2)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.2) (1.18.2)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.2) (0.34.2)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.2) (1.0.8)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.2) (0.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow-gpu==1.15.2) (46.1.3)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (3.2.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2) (1.0.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow-gpu==1.15.2) (2.10.0)

# %% [markdown]
# # **Setting up constants**

# %%
TRAINING_DIR = '/content/drive/My Drive/CAI/iron_calcium/training'
TEST_DIR = '/content/drive/My Drive/CAI/iron_calcium/tests'
SEED = 101
IMAGE_SIZE = 224
CHANNELS = 3 # red, green, blue
CLASSES = 3

# %% [markdown]
# #**Checking Up data**

# %%
# SNIPPET TO LOAD DATA FROM DIRECTORY, FOR MANUAL WORK WITHOUT GENERATORS

import cv2
import glob
import numpy as np
import matplotlib.pyplot as plt

x_data = []
images_calcium = glob.glob (TRAINING_DIR + '/calcium/*.jpg')
images_iron = glob.glob (TRAINING_DIR + '/iron/*.jpg')
images_hp = glob.glob (TRAINING_DIR + '/healthy/*.jpg')

print ('calcium count ' + str(len(images_calcium)))
print ('iron count ' + str(len(images_iron)))
print ('healthy count ' + str(len(images_hp)))
# Out:
# calcium count 13
# iron count 12
# healthy count 12

# %% [markdown]
# # **Cycle Learning Rate**

# %%
from keras.callbacks import Callback
from keras import backend as K
import numpy as np


class CyclicLR(Callback):
    """This callback implements a cyclical learning rate policy (CLR).
    The method cycles the learning rate between two boundaries with
    some constant frequency.
    # Arguments
        base_lr: initial learning rate which is the
            lower boundary in the cycle.
        max_lr: upper boundary in the cycle. Functionally,
            it defines the cycle amplitude (max_lr - base_lr).
            The lr at any cycle is the sum of base_lr
            and some scaling of the amplitude; therefore
            max_lr may not actually be reached depending on
            scaling function.
        step_size: number of training iterations per
            half cycle. Authors suggest setting step_size
            2-8 x training iterations in epoch.
        mode: one of {triangular, triangular2, exp_range}.
            Default 'triangular'.
            Values correspond to policies detailed above.
            If scale_fn is not None, this argument is ignored.
        gamma: constant in 'exp_range' scaling function:
            gamma**(cycle iterations)
        scale_fn: Custom scaling policy defined by a single
            argument lambda function, where
            0 <= scale_fn(x) <= 1 for all x >= 0.
            mode paramater is ignored
        scale_mode: {'cycle', 'iterations'}.
            Defines whether scale_fn is evaluated on
            cycle number or cycle iterations (training
            iterations since start of cycle). Default is 'cycle'.

    The amplitude of the cycle can be scaled on a per-iteration or
    per-cycle basis.
    This class has three built-in policies, as put forth in the paper.
    "triangular":
        A basic triangular cycle w/ no amplitude scaling.
    "triangular2":
        A basic triangular cycle that scales initial amplitude by half each cycle.
    "exp_range":
        A cycle that scales initial amplitude by gamma**(cycle iterations) at each
        cycle iteration.
    For more detail, please see paper.

    # Example for CIFAR-10 w/ batch size 100:
        ```python
            clr = CyclicLR(base_lr=0.001, max_lr=0.006,
                                step_size=2000., mode='triangular')
            model.fit(X_train, Y_train, callbacks=[clr])
        ```

    Class also supports custom scaling functions:
        ```python
            clr_fn = lambda x: 0.5*(1+np.sin(x*np.pi/2.))
            clr = CyclicLR(base_lr=0.001, max_lr=0.006,
                                step_size=2000., scale_fn=clr_fn,
                                scale_mode='cycle')
            model.fit(X_train, Y_train, callbacks=[clr])
        ```

    # References

      - [Cyclical Learning Rates for Training Neural Networks](
      https://arxiv.org/abs/1506.01186)
    """

    def __init__(
            self,
            base_lr=0.001,
            max_lr=0.006,
            step_size=2000.,
            mode='triangular',
            gamma=1.,
            scale_fn=None,
            scale_mode='cycle'):
        super(CyclicLR, self).__init__()

        if mode not in ['triangular', 'triangular2',
                        'exp_range']:
            raise KeyError("mode must be one of 'triangular', "
                           "'triangular2', or 'exp_range'")
        self.base_lr = base_lr
        self.max_lr = max_lr
        self.step_size = step_size
        self.mode = mode
        self.gamma = gamma
        if scale_fn is None:
            if self.mode == 'triangular':
                self.scale_fn = lambda x: 1.
                self.scale_mode = 'cycle'
            elif self.mode == 'triangular2':
                self.scale_fn = lambda x: 1 / (2.**(x - 1))
                self.scale_mode = 'cycle'
            elif self.mode == 'exp_range':
                self.scale_fn = lambda x: gamma ** x
                self.scale_mode = 'iterations'
        else:
            self.scale_fn = scale_fn
            self.scale_mode = scale_mode
        self.clr_iterations = 0.
        self.trn_iterations = 0.
        self.history = {}

        self._reset()

    def _reset(self, new_base_lr=None, new_max_lr=None,
               new_step_size=None):
        """Resets cycle iterations.
        Optional boundary/step size adjustment.
        """
        if new_base_lr is not None:
            self.base_lr = new_base_lr
        if new_max_lr is not None:
            self.max_lr = new_max_lr
        if new_step_size is not None:
            self.step_size = new_step_size
        self.clr_iterations = 0.

    def clr(self):
        cycle = np.floor(1 + self.clr_iterations / (2 * self.step_size))
        x = np.abs(self.clr_iterations / self.step_size - 2 * cycle + 1)
        if self.scale_mode == 'cycle':
            return self.base_lr + (self.max_lr - self.base_lr) * \
                np.maximum(0, (1 - x)) * self.scale_fn(cycle)
        else:
            return self.base_lr + (self.max_lr - self.base_lr) * \
                np.maximum(0, (1 - x)) * self.scale_fn(self.clr_iterations)

    def on_train_begin(self, logs={}):
        logs = logs or {}

        if self.clr_iterations == 0:
            K.set_value(self.model.optimizer.lr, self.base_lr)
        else:
            K.set_value(self.model.optimizer.lr, self.clr())

    def on_batch_end(self, epoch, logs=None):

        logs = logs or {}
        self.trn_iterations += 1
        self.clr_iterations += 1
        K.set_value(self.model.optimizer.lr, self.clr())

        self.history.setdefault(
            'lr', []).append(
            K.get_value(
                self.model.optimizer.lr))
        self.history.setdefault('iterations', []).append(self.trn_iterations)

        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        logs['lr'] = K.get_value(self.model.optimizer.lr)

# %% [markdown]
# #**Adabound custom optimizer**

# %%
from keras import backend as K
from keras.optimizers import Optimizer


class AdaBound(Optimizer):
    """AdaBound optimizer.

    Default parameters follow those provided in the original paper.

    # Arguments
        lr: float >= 0. Learning rate.
        final_lr: float >= 0. Final learning rate.
        beta_1: float, 0 < beta < 1. Generally close to 1.
        beta_2: float, 0 < beta < 1. Generally close to 1.
        gamma: float >= 0. Convergence speed of the bound function.
        epsilon: float >= 0. Fuzz factor. If `None`, defaults to `K.epsilon()`.
        decay: float >= 0. Learning rate decay over each update.
        weight_decay: Weight decay weight.
        amsbound: boolean. Whether to apply the AMSBound variant of this
            algorithm.

    # References
        - [Adaptive Gradient Methods with Dynamic Bound of Learning Rate]
          (https://openreview.net/forum?id=Bkg3g2R9FX)
        - [Adam - A Method for Stochastic Optimization]
          (https://arxiv.org/abs/1412.6980v8)
        - [On the Convergence of Adam and Beyond]
          (https://openreview.net/forum?id=ryQu7f-RZ)
    """

    def __init__(self, lr=0.001, final_lr=0.1, beta_1=0.9, beta_2=0.999, gamma=1e-3,
                 epsilon=None, decay=0., amsbound=False, weight_decay=0.0, **kwargs):
        super(AdaBound, self).__init__(**kwargs)

        if not 0. <= gamma <= 1.:
            raise ValueError("Invalid `gamma` parameter. Must lie in [0, 1] range.")

        with K.name_scope(self.__class__.__name__):
            self.iterations = K.variable(0, dtype='int64', name='iterations')
            self.lr = K.variable(lr, name='lr')
            self.beta_1 = K.variable(beta_1, name='beta_1')
            self.beta_2 = K.variable(beta_2, name='beta_2')
            self.decay = K.variable(decay, name='decay')

        self.final_lr = final_lr
        self.gamma = gamma

        if epsilon is None:
            epsilon = K.epsilon()
        self.epsilon = epsilon
        self.initial_decay = decay
        self.amsbound = amsbound

        self.weight_decay = float(weight_decay)
        self.base_lr = float(lr)

    def get_updates(self, loss, params):
        grads = self.get_gradients(loss, params)
        self.updates = [K.update_add(self.iterations, 1)]

        lr = self.lr
        if self.initial_decay > 0:
            lr = lr * (1. / (1. + self.decay * K.cast(self.iterations,
                                                      K.dtype(self.decay))))

        t = K.cast(self.iterations, K.floatx()) + 1

        # Applies bounds on actual learning rate
        step_size = lr * (K.sqrt(1. - K.pow(self.beta_2, t)) /
                          (1. - K.pow(self.beta_1, t)))

        final_lr = self.final_lr * lr / self.base_lr
        lower_bound = final_lr * (1. - 1. / (self.gamma * t + 1.))
        upper_bound = final_lr * (1. + 1. / (self.gamma * t))

        ms = [K.zeros(K.int_shape(p), dtype=K.dtype(p)) for p in params]
        vs = [K.zeros(K.int_shape(p), dtype=K.dtype(p)) for p in params]
        if self.amsbound:
            vhats = [K.zeros(K.int_shape(p), dtype=K.dtype(p)) for p in params]
        else:
            vhats = [K.zeros(1) for _ in params]
        self.weights = [self.iterations] + ms + vs + vhats

        for p, g, m, v, vhat in zip(params, grads, ms, vs, vhats):
            # apply weight decay
            if self.weight_decay != 0.:
                g += self.weight_decay * K.stop_gradient(p)

            m_t = (self.beta_1 * m) + (1. - self.beta_1) * g
            v_t = (self.beta_2 * v) + (1. - self.beta_2) * K.square(g)

            if self.amsbound:
                vhat_t = K.maximum(vhat, v_t)
                denom = (K.sqrt(vhat_t) + self.epsilon)
                self.updates.append(K.update(vhat, vhat_t))
            else:
                denom = (K.sqrt(v_t) + self.epsilon)

            # Compute the bounds
            step_size_p = step_size * K.ones_like(denom)
            step_size_p_bound = step_size_p / denom
            bounded_lr_t = m_t * K.minimum(K.maximum(step_size_p_bound,
                                                     lower_bound), upper_bound)

            p_t = p - bounded_lr_t

            self.updates.append(K.update(m, m_t))
            self.updates.append(K.update(v, v_t))
            new_p = p_t

            # Apply constraints.
            if getattr(p, 'constraint', None) is not None:
                new_p = p.constraint(new_p)

            self.updates.append(K.update(p, new_p))
        return self.updates

    def get_config(self):
        config = {'lr': float(K.get_value(self.lr)),
                  'final_lr': float(self.final_lr),
                  'beta_1': float(K.get_value(self.beta_1)),
                  'beta_2': float(K.get_value(self.beta_2)),
                  'gamma': float(self.gamma),
                  'decay': float(K.get_value(self.decay)),
                  'epsilon': self.epsilon,
                  'weight_decay': self.weight_decay,
                  'amsbound': self.amsbound}
        base_config = super(AdaBound, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

# %% [markdown]
# # **Function definitions**
#
#
#
# *   buildModel
# *   buildModelFromDisk
# *   getHyperparameters
# *   getTrainingHyperparameters
# *   buildSampleFromDisk

# %% [markdown]
# ## **Hyperparameters**

# %%
'''
  Hyperparameters used to compile the model
'''

from keras.optimizers import RMSprop, Adadelta, Adam, SGD

def getHyperparameters():
  OPTIMIZER = SGD(1e-3)
  LOSS = 'categorical_crossentropy'
  METRICS = ['categorical_accuracy']

  return (LOSS, OPTIMIZER, METRICS)

# %% [markdown]
# ## **Training parameters**

# %%
'''
  Hyperparameters that are used only for training phase, e.g, number of epochs,
  batch size.
'''

from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping

def getTrainingHyperparameters():
  reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=45, verbose=1) 
  early_stop = EarlyStopping(patience=30, restore_best_weights=True)
  model_checkpoint = ModelCheckpoint('./checkpoint.h5', monitor='val_loss', save_best_only=True, verbose=1)
  cycle_learning_rate = CyclicLR(1e-7, 1e-1, step_size=100, mode='triangular2') 
  CALLBACK = [
    reduce_lr,
    model_checkpoint
  ]

  BATCH_SIZE = 16
  EPOCHS = 100

  return (EPOCHS, BATCH_SIZE, CALLBACK)

# %% [markdown]
# ##**buildModel**

# %%
'''
  Model architecture definiton, including layers, initializers, activations and more
'''

from keras.layers import Dense, Input, Conv2D, Flatten, MaxPool2D, Dropout, GlobalAveragePooling2D, BatchNormalization, LeakyReLU
from keras.models import Model
from keras.initializers import Constant
from keras.regularizers import l2

kernel_regularizer = l2(0.1)
activity_regularizer = l2(0.001)

def buildModel():
  i = Input(shape=(IMAGE_SIZE, IMAGE_SIZE, CHANNELS))
  d = Conv2D(filters=16, kernel_size=(7,7), kernel_initializer='glorot_uniform', bias_initializer=Constant(0.1))(i)
  d = LeakyReLU(0.01)(d)
  d = BatchNormalization()(d)
  d = Conv2D(filters=32, kernel_size=(7,7) , kernel_initializer='glorot_uniform', bias_initializer=Constant(0.1))(d)
  d = LeakyReLU(0.01)(d)
  d = MaxPool2D(pool_size=(2,2))(d)
  d = BatchNormalization()(d)
  d = Conv2D(filters=64, kernel_size=(5,5), kernel_initializer='glorot_uniform', bias_initializer=Constant(0.1))(d)
  d = LeakyReLU(0.01)(d)
  d = GlobalAveragePooling2D()(d)
  d = BatchNormalization()(d)
  d = Dense(64, activation='relu', kernel_initializer='glorot_uniform', bias_initializer=Constant(0.1), activity_regularizer=activity_regularizer)(d)
  d = Dropout(0.30)(d)
  d = Dense(CLASSES, activation='softmax', kernel_initializer='glorot_uniform', bias_initializer=Constant(0.1))(d)

  model = Model(inputs=i, outputs=d)

  (LOSS, OPTIMIZER, METRICS) = getHyperparameters()

  model.compile(loss=LOSS, optimizer=OPTIMIZER, metrics=METRICS)

  return model

# %% [markdown]
# ##**buildModelFromDisk**

# %%
from keras.models import load_model

def buildModelFromDisk(path='model.h5'):
  model = load_model(path, compile=False)

  return model

# %% [markdown]
# ##**buildSampleFromDisk**

# %%
import numpy as np
from keras.preprocessing import image

def buildSampleFromDisk(img_path: str):
  original_test_image = image.load_img(img_path, target_size=(IMAGE_SIZE,IMAGE_SIZE))
    
  test_image = image.img_to_array(original_test_image)

  test_tensor = np.reshape(test_image, (1, IMAGE_SIZE, IMAGE_SIZE, CHANNELS))

  test_tensor = test_tensor / 255

  return (original_test_image, test_tensor)

# %% [markdown]
# ## **changeImageColorSpaceToHSV**

# %%
import cv2
import numpy as np

def changeImageColorSpaceToHSV(image):
    image = np.array(image)
    hsv_image = cv2.cvtColor(image,cv2.COLOR_RGB2HSV)

    return hsv_image

# %% [markdown]
# # **Training**

# %%
(LOSS, OPTIMIZER, METRICS) = getHyperparameters()
(EPOCHS, BATCH_SIZE, CALLBACKS) = getTrainingHyperparameters()

# %% [markdown]
# ## **Generators**

# %%
from keras.preprocessing.image import ImageDataGenerator
# Create data generators to load images from disk and do data augmentation


data_generator = ImageDataGenerator(
  rescale=1./255,
  validation_split=0.2,
  rotation_range = 10,
  width_shift_range=0.2
)

train_generator = data_generator.flow_from_directory(
  TRAINING_DIR,
  target_size=(IMAGE_SIZE, IMAGE_SIZE),
  shuffle=True,
  seed=SEED,  
  class_mode='categorical',
  batch_size=BATCH_SIZE,
  subset="training"
)

validation_generator = data_generator.flow_from_directory(
  TRAINING_DIR,
  target_size=(IMAGE_SIZE, IMAGE_SIZE),
  shuffle=False,
  seed=SEED,
  class_mode='categorical',
  batch_size=BATCH_SIZE,
  subset="validation"
)
# Out:
# Found 31 images belonging to 3 classes.
# Found 6 images belonging to 3 classes.

# %% [markdown]
# ##**Fit**

# %%
import matplotlib.pyplot as plt
import numpy as np 
from keras.metrics import categorical_crossentropy, categorical_accuracy

model = buildModel()

model.summary()

history = model.fit_generator(
  train_generator,
  epochs=EPOCHS,
  validation_data=validation_generator,
  shuffle=True,
  callbacks=CALLBACKS
)

model.save('./model.h5')

# Plot step by step movements of the accuracy metric

plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 218, 218, 16)      2368
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 218, 218, 16)      0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 218, 218, 16)      64
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 212, 212, 32)      25120
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 212, 212, 32)      0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 106, 106, 32)      0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 106, 106, 32)      128
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 102, 102, 64)      51264
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 102, 102, 64)      0
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 64)                0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 64)                256
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 83,555
# Trainable params: 83,331
# Non-trainable params: 224
# _________________________________________________________________
# Epoch 1/100
# 2/2 [==============================] - 2s 1s/step - loss: 2.3531 - categorical_accuracy: 0.2582 - val_loss: 2.7776 - val_categorical_accuracy: 0.1667
#
# Epoch 00001: val_loss improved from inf to 2.77755, saving model to ./checkpoint.h5
# Epoch 2/100
# 2/2 [==============================] - 1s 588ms/step - loss: 1.6620 - categorical_accuracy: 0.3544 - val_loss: 2.2107 - val_categorical_accuracy: 0.3333
#
# Epoch 00002: val_loss improved from 2.77755 to 2.21070, saving model to ./checkpoint.h5
# Epoch 3/100
# 2/2 [==============================] - 2s 799ms/step - loss: 1.2724 - categorical_accuracy: 0.6470 - val_loss: 5.7948 - val_categorical_accuracy: 0.3333
#
# Epoch 00003: val_loss did not improve from 2.21070
# Epoch 4/100
# 2/2 [==============================] - 2s 816ms/step - loss: 1.5283 - categorical_accuracy: 0.4849 - val_loss: 1.7815 - val_categorical_accuracy: 0.3333
#
# Epoch 00004: val_loss improved from 2.21070 to 1.78154, saving model to ./checkpoint.h5
# Epoch 5/100
# 2/2 [==============================] - 2s 802ms/step - loss: 1.2494 - categorical_accuracy: 0.6470 - val_loss: 1.7141 - val_categorical_accuracy: 0.5000
#
# Epoch 00005: val_loss improved from 1.78154 to 1.71414, saving model to ./checkpoint.h5
# Epoch 6/100
# 2/2 [==============================] - 2s 806ms/step - loss: 1.2273 - categorical_accuracy: 0.6112 - val_loss: 1.7096 - val_categorical_accuracy: 0.1667
#
# Epoch 00006: val_loss improved from 1.71414 to 1.70957, saving model to ./checkpoint.h5
# Epoch 7/100
# 2/2 [==============================] - 2s 787ms/step - loss: 1.0013 - categorical_accuracy: 0.8063 - val_loss: 1.5005 - val_categorical_accuracy: 0.3333
#
# Epoch 00007: val_loss improved from 1.70957 to 1.50054, saving model to ./checkpoint.h5
# Epoch 8/100
# 2/2 [==============================] - 2s 802ms/step - loss: 1.0053 - categorical_accuracy: 0.7102 - val_loss: 1.5435 - val_categorical_accuracy: 0.3333
#
# Epoch 00008: val_loss did not improve from 1.50054
# Epoch 9/100
# 2/2 [==============================] - 2s 818ms/step - loss: 0.9896 - categorical_accuracy: 0.8035 - val_loss: 1.8975 - val_categorical_accuracy: 0.1667
#
# Epoch 00009: val_loss did not improve from 1.50054
# Epoch 10/100
# 2/2 [==============================] - 2s 814ms/step - loss: 0.9515 - categorical_accuracy: 0.7733 - val_loss: 3.6292 - val_categorical_accuracy: 0.3333
#
# Epoch 00010: val_loss did not improve from 1.50054
# Epoch 11/100
# 2/2 [==============================] - 2s 804ms/step - loss: 1.1137 - categorical_accuracy: 0.6099 - val_loss: 0.9623 - val_categorical_accuracy: 0.6667
#
# Epoch 00011: val_loss improved from 1.50054 to 0.96226, saving model to ./checkpoint.h5
# Epoch 12/100
# 2/2 [==============================] - 2s 786ms/step - loss: 0.8635 - categorical_accuracy: 0.8049 - val_loss: 1.3928 - val_categorical_accuracy: 0.5000
#
# Epoch 00012: val_loss did not improve from 0.96226
# Epoch 13/100
# 2/2 [==============================] - 2s 794ms/step - loss: 1.0895 - categorical_accuracy: 0.7390 - val_loss: 3.2287 - val_categorical_accuracy: 0.1667
#
# Epoch 00013: val_loss did not improve from 0.96226
# Epoch 14/100
# 2/2 [==============================] - 2s 799ms/step - loss: 1.0407 - categorical_accuracy: 0.7706 - val_loss: 7.2310 - val_categorical_accuracy: 0.3333
#
# Epoch 00014: val_loss did not improve from 0.96226
# Epoch 15/100
# 2/2 [==============================] - 2s 798ms/step - loss: 0.8695 - categorical_accuracy: 0.8695 - val_loss: 5.5620 - val_categorical_accuracy: 0.3333
#
# Epoch 00015: val_loss did not improve from 0.96226
# Epoch 16/100
# 2/2 [==============================] - 2s 789ms/step - loss: 0.8100 - categorical_accuracy: 0.8709 - val_loss: 3.8787 - val_categorical_accuracy: 0.3333
#
# Epoch 00016: val_loss did not improve from 0.96226
# Epoch 17/100
# 2/2 [==============================] - 2s 810ms/step - loss: 0.7301 - categorical_accuracy: 0.9039 - val_loss: 1.5301 - val_categorical_accuracy: 0.1667
#
# Epoch 00017: val_loss did not improve from 0.96226
# Epoch 18/100
# 2/2 [==============================] - 2s 803ms/step - loss: 0.7805 - categorical_accuracy: 0.8365 - val_loss: 4.0676 - val_categorical_accuracy: 0.3333
#
# Epoch 00018: val_loss did not improve from 0.96226
# Epoch 19/100
# 2/2 [==============================] - 2s 801ms/step - loss: 0.7259 - categorical_accuracy: 0.8407 - val_loss: 0.9280 - val_categorical_accuracy: 0.6667
#
# Epoch 00019: val_loss improved from 0.96226 to 0.92805, saving model to ./checkpoint.h5
# Epoch 20/100
# 2/2 [==============================] - 2s 797ms/step - loss: 0.8075 - categorical_accuracy: 0.8379 - val_loss: 1.8181 - val_categorical_accuracy: 0.1667
#
# Epoch 00020: val_loss did not improve from 0.92805
# Epoch 21/100
# 2/2 [==============================] - 2s 813ms/step - loss: 0.6658 - categorical_accuracy: 0.9354 - val_loss: 1.5816 - val_categorical_accuracy: 0.1667
#
# Epoch 00021: val_loss did not improve from 0.92805
# Epoch 22/100
# 2/2 [==============================] - 2s 813ms/step - loss: 0.6435 - categorical_accuracy: 0.9670 - val_loss: 1.7014 - val_categorical_accuracy: 0.3333
#
# Epoch 00022: val_loss did not improve from 0.92805
# Epoch 23/100
# 2/2 [==============================] - 2s 798ms/step - loss: 0.6403 - categorical_accuracy: 0.9684 - val_loss: 1.2394 - val_categorical_accuracy: 0.3333
#
# Epoch 00023: val_loss did not improve from 0.92805
# Epoch 24/100
# 2/2 [==============================] - 2s 813ms/step - loss: 0.6661 - categorical_accuracy: 0.9039 - val_loss: 1.2336 - val_categorical_accuracy: 0.3333
#
# Epoch 00024: val_loss did not improve from 0.92805
# Epoch 25/100
# 2/2 [==============================] - 2s 806ms/step - loss: 0.5633 - categorical_accuracy: 0.9670 - val_loss: 1.5337 - val_categorical_accuracy: 0.3333
#
# Epoch 00025: val_loss did not improve from 0.92805
# Epoch 26/100
# 2/2 [==============================] - 2s 837ms/step - loss: 0.6161 - categorical_accuracy: 0.9039 - val_loss: 1.1909 - val_categorical_accuracy: 0.5000
#
# Epoch 00026: val_loss did not improve from 0.92805
# Epoch 27/100
# 2/2 [==============================] - 2s 807ms/step - loss: 0.6058 - categorical_accuracy: 0.9025 - val_loss: 0.9834 - val_categorical_accuracy: 0.8333
#
# Epoch 00027: val_loss did not improve from 0.92805
# Epoch 28/100
# 2/2 [==============================] - 2s 797ms/step - loss: 0.6073 - categorical_accuracy: 0.9341 - val_loss: 1.1586 - val_categorical_accuracy: 0.6667
#
# Epoch 00028: val_loss did not improve from 0.92805
# Epoch 29/100
# 2/2 [==============================] - 2s 790ms/step - loss: 0.7708 - categorical_accuracy: 0.7761 - val_loss: 1.3980 - val_categorical_accuracy: 0.5000
#
# Epoch 00029: val_loss did not improve from 0.92805
# Epoch 30/100
# 2/2 [==============================] - 2s 798ms/step - loss: 0.6124 - categorical_accuracy: 0.9039 - val_loss: 1.1092 - val_categorical_accuracy: 0.5000
#
# Epoch 00030: val_loss did not improve from 0.92805
# Epoch 31/100
# 2/2 [==============================] - 2s 807ms/step - loss: 0.5778 - categorical_accuracy: 0.9354 - val_loss: 1.0778 - val_categorical_accuracy: 0.6667
#
# Epoch 00031: val_loss did not improve from 0.92805
# Epoch 32/100
# 2/2 [==============================] - 2s 803ms/step - loss: 0.4829 - categorical_accuracy: 1.0000 - val_loss: 0.9085 - val_categorical_accuracy: 0.6667
#
# Epoch 00032: val_loss improved from 0.92805 to 0.90848, saving model to ./checkpoint.h5
# Epoch 33/100
# 2/2 [==============================] - 2s 777ms/step - loss: 0.5139 - categorical_accuracy: 1.0000 - val_loss: 0.9603 - val_categorical_accuracy: 0.8333
#
# Epoch 00033: val_loss did not improve from 0.90848
# Epoch 34/100
# 2/2 [==============================] - 2s 802ms/step - loss: 0.4700 - categorical_accuracy: 1.0000 - val_loss: 1.0144 - val_categorical_accuracy: 0.8333
#
# Epoch 00034: val_loss did not improve from 0.90848
# Epoch 35/100
# 2/2 [==============================] - 2s 792ms/step - loss: 0.4606 - categorical_accuracy: 1.0000 - val_loss: 0.8208 - val_categorical_accuracy: 0.8333
#
# Epoch 00035: val_loss improved from 0.90848 to 0.82076, saving model to ./checkpoint.h5
# Epoch 36/100
# 2/2 [==============================] - 2s 793ms/step - loss: 0.4698 - categorical_accuracy: 1.0000 - val_loss: 1.2075 - val_categorical_accuracy: 0.5000
#
# Epoch 00036: val_loss did not improve from 0.82076
# Epoch 37/100
# 2/2 [==============================] - 2s 811ms/step - loss: 0.5186 - categorical_accuracy: 0.9684 - val_loss: 0.7976 - val_categorical_accuracy: 0.8333
#
# Epoch 00037: val_loss improved from 0.82076 to 0.79759, saving model to ./checkpoint.h5
# Epoch 38/100
# 2/2 [==============================] - 2s 804ms/step - loss: 0.4758 - categorical_accuracy: 1.0000 - val_loss: 1.0684 - val_categorical_accuracy: 0.8333
#
# Epoch 00038: val_loss did not improve from 0.79759
# Epoch 39/100
# 2/2 [==============================] - 2s 801ms/step - loss: 0.6351 - categorical_accuracy: 0.8723 - val_loss: 1.7702 - val_categorical_accuracy: 0.3333
#
# Epoch 00039: val_loss did not improve from 0.79759
# Epoch 40/100
# 2/2 [==============================] - 2s 798ms/step - loss: 0.6832 - categorical_accuracy: 0.8723 - val_loss: 3.2541 - val_categorical_accuracy: 0.1667
#
# Epoch 00040: val_loss did not improve from 0.79759
# Epoch 41/100
# 2/2 [==============================] - 2s 799ms/step - loss: 0.5600 - categorical_accuracy: 0.9368 - val_loss: 0.9630 - val_categorical_accuracy: 0.6667
#
# Epoch 00041: val_loss did not improve from 0.79759
# Epoch 42/100
# 2/2 [==============================] - 2s 801ms/step - loss: 0.5034 - categorical_accuracy: 0.9354 - val_loss: 0.8963 - val_categorical_accuracy: 0.6667
#
# Epoch 00042: val_loss did not improve from 0.79759
# Epoch 43/100
# 2/2 [==============================] - 2s 800ms/step - loss: 0.6039 - categorical_accuracy: 0.9354 - val_loss: 0.8341 - val_categorical_accuracy: 0.8333
#
# Epoch 00043: val_loss did not improve from 0.79759
# Epoch 44/100
# 2/2 [==============================] - 2s 812ms/step - loss: 0.5131 - categorical_accuracy: 0.9354 - val_loss: 1.1659 - val_categorical_accuracy: 0.5000
#
# Epoch 00044: val_loss did not improve from 0.79759
# Epoch 45/100
# 2/2 [==============================] - 2s 808ms/step - loss: 0.5109 - categorical_accuracy: 0.9670 - val_loss: 0.8548 - val_categorical_accuracy: 0.8333
#
# Epoch 00045: val_loss did not improve from 0.79759
# Epoch 46/100
# 2/2 [==============================] - 2s 802ms/step - loss: 0.4835 - categorical_accuracy: 0.9684 - val_loss: 1.2123 - val_categorical_accuracy: 0.5000
#
# Epoch 00046: val_loss did not improve from 0.79759
# Epoch 47/100
# 2/2 [==============================] - 2s 792ms/step - loss: 0.4081 - categorical_accuracy: 1.0000 - val_loss: 1.1384 - val_categorical_accuracy: 0.5000
#
# Epoch 00047: val_loss did not improve from 0.79759
# Epoch 48/100
# 2/2 [==============================] - 2s 808ms/step - loss: 0.4825 - categorical_accuracy: 0.9670 - val_loss: 2.2946 - val_categorical_accuracy: 0.1667
#
# Epoch 00048: val_loss did not improve from 0.79759
# Epoch 49/100
# 2/2 [==============================] - 2s 794ms/step - loss: 0.4510 - categorical_accuracy: 0.9670 - val_loss: 1.3345 - val_categorical_accuracy: 0.5000
#
# Epoch 00049: val_loss did not improve from 0.79759
# Epoch 50/100
# 2/2 [==============================] - 2s 783ms/step - loss: 0.4865 - categorical_accuracy: 0.9684 - val_loss: 1.0416 - val_categorical_accuracy: 0.6667
#
# Epoch 00050: val_loss did not improve from 0.79759
# Epoch 51/100
# 2/2 [==============================] - 2s 835ms/step - loss: 0.4514 - categorical_accuracy: 1.0000 - val_loss: 1.3188 - val_categorical_accuracy: 0.5000
#
# Epoch 00051: val_loss did not improve from 0.79759
# Epoch 52/100
# 2/2 [==============================] - 2s 785ms/step - loss: 0.4193 - categorical_accuracy: 0.9025 - val_loss: 1.1971 - val_categorical_accuracy: 0.5000
#
# Epoch 00052: val_loss did not improve from 0.79759
# Epoch 53/100
# 2/2 [==============================] - 2s 802ms/step - loss: 0.4052 - categorical_accuracy: 0.9684 - val_loss: 1.1570 - val_categorical_accuracy: 0.3333
#
# Epoch 00053: val_loss did not improve from 0.79759
# Epoch 54/100
# 2/2 [==============================] - 2s 794ms/step - loss: 0.7000 - categorical_accuracy: 0.9011 - val_loss: 8.3621 - val_categorical_accuracy: 0.3333
#
# Epoch 00054: val_loss did not improve from 0.79759
# Epoch 55/100
# 2/2 [==============================] - 2s 801ms/step - loss: 0.6959 - categorical_accuracy: 0.8695 - val_loss: 7.4680 - val_categorical_accuracy: 0.3333
#
# Epoch 00055: val_loss did not improve from 0.79759
# Epoch 56/100
# 2/2 [==============================] - 2s 801ms/step - loss: 0.5525 - categorical_accuracy: 0.9039 - val_loss: 2.0233 - val_categorical_accuracy: 0.3333
#
# Epoch 00056: val_loss did not improve from 0.79759
# Epoch 57/100
# 2/2 [==============================] - 2s 814ms/step - loss: 0.5251 - categorical_accuracy: 0.9670 - val_loss: 2.3557 - val_categorical_accuracy: 0.3333
#
# Epoch 00057: val_loss did not improve from 0.79759
# Epoch 58/100
# 2/2 [==============================] - 2s 785ms/step - loss: 0.4428 - categorical_accuracy: 1.0000 - val_loss: 1.1908 - val_categorical_accuracy: 0.6667
#
# Epoch 00058: val_loss did not improve from 0.79759
# Epoch 59/100
# 2/2 [==============================] - 2s 809ms/step - loss: 0.4090 - categorical_accuracy: 1.0000 - val_loss: 3.2582 - val_categorical_accuracy: 0.3333
#
# Epoch 00059: val_loss did not improve from 0.79759
# Epoch 60/100
# 2/2 [==============================] - 2s 790ms/step - loss: 0.3890 - categorical_accuracy: 0.9684 - val_loss: 1.2153 - val_categorical_accuracy: 0.3333
#
# Epoch 00060: val_loss did not improve from 0.79759
# Epoch 61/100
# 2/2 [==============================] - 2s 798ms/step - loss: 0.4060 - categorical_accuracy: 1.0000 - val_loss: 1.5497 - val_categorical_accuracy: 0.3333
#
# Epoch 00061: val_loss did not improve from 0.79759
# Epoch 62/100
# 2/2 [==============================] - 2s 812ms/step - loss: 0.4888 - categorical_accuracy: 0.9011 - val_loss: 0.8101 - val_categorical_accuracy: 0.6667
#
# Epoch 00062: val_loss did not improve from 0.79759
# Epoch 63/100
# 2/2 [==============================] - 2s 805ms/step - loss: 0.3784 - categorical_accuracy: 1.0000 - val_loss: 0.6785 - val_categorical_accuracy: 0.8333
#
# Epoch 00063: val_loss improved from 0.79759 to 0.67849, saving model to ./checkpoint.h5
# Epoch 64/100
# 2/2 [==============================] - 2s 797ms/step - loss: 0.4271 - categorical_accuracy: 0.9670 - val_loss: 2.6028 - val_categorical_accuracy: 0.3333
#
# Epoch 00064: val_loss did not improve from 0.67849
# Epoch 65/100
# 2/2 [==============================] - 2s 823ms/step - loss: 0.4381 - categorical_accuracy: 1.0000 - val_loss: 1.6412 - val_categorical_accuracy: 0.3333
#
# Epoch 00065: val_loss did not improve from 0.67849
# Epoch 66/100
# 2/2 [==============================] - 2s 789ms/step - loss: 0.4448 - categorical_accuracy: 0.9670 - val_loss: 1.2376 - val_categorical_accuracy: 0.5000
#
# Epoch 00066: val_loss did not improve from 0.67849
# Epoch 67/100
# 2/2 [==============================] - 2s 801ms/step - loss: 0.3739 - categorical_accuracy: 1.0000 - val_loss: 1.9740 - val_categorical_accuracy: 0.1667
#
# Epoch 00067: val_loss did not improve from 0.67849
# Epoch 68/100
# 2/2 [==============================] - 2s 807ms/step - loss: 0.3622 - categorical_accuracy: 1.0000 - val_loss: 1.3779 - val_categorical_accuracy: 0.1667
#
# Epoch 00068: val_loss did not improve from 0.67849
# Epoch 69/100
# 2/2 [==============================] - 2s 792ms/step - loss: 0.4284 - categorical_accuracy: 1.0000 - val_loss: 0.6541 - val_categorical_accuracy: 0.8333
#
# Epoch 00069: val_loss improved from 0.67849 to 0.65413, saving model to ./checkpoint.h5
# Epoch 70/100
# 2/2 [==============================] - 2s 803ms/step - loss: 0.4984 - categorical_accuracy: 0.9684 - val_loss: 0.6168 - val_categorical_accuracy: 0.8333
#
# Epoch 00070: val_loss improved from 0.65413 to 0.61683, saving model to ./checkpoint.h5
# Epoch 71/100
# 2/2 [==============================] - 2s 785ms/step - loss: 0.3609 - categorical_accuracy: 1.0000 - val_loss: 1.2362 - val_categorical_accuracy: 0.5000
#
# Epoch 00071: val_loss did not improve from 0.61683
# Epoch 72/100
# 2/2 [==============================] - 2s 815ms/step - loss: 0.3429 - categorical_accuracy: 1.0000 - val_loss: 0.9185 - val_categorical_accuracy: 0.3333
#
# Epoch 00072: val_loss did not improve from 0.61683
# Epoch 73/100
# 2/2 [==============================] - 2s 808ms/step - loss: 0.4582 - categorical_accuracy: 0.9025 - val_loss: 0.7051 - val_categorical_accuracy: 0.8333
#
# Epoch 00073: val_loss did not improve from 0.61683
# Epoch 74/100
# 2/2 [==============================] - 2s 817ms/step - loss: 0.4413 - categorical_accuracy: 0.9341 - val_loss: 2.8687 - val_categorical_accuracy: 0.3333
#
# Epoch 00074: val_loss did not improve from 0.61683
# Epoch 75/100
# 2/2 [==============================] - 2s 808ms/step - loss: 0.3746 - categorical_accuracy: 1.0000 - val_loss: 1.6843 - val_categorical_accuracy: 0.3333
#
# Epoch 00075: val_loss did not improve from 0.61683
# Epoch 76/100
# 2/2 [==============================] - 2s 832ms/step - loss: 0.3638 - categorical_accuracy: 0.9684 - val_loss: 0.8196 - val_categorical_accuracy: 0.8333
#
# Epoch 00076: val_loss did not improve from 0.61683
# Epoch 77/100
# 2/2 [==============================] - 2s 814ms/step - loss: 0.3704 - categorical_accuracy: 0.9670 - val_loss: 3.7503 - val_categorical_accuracy: 0.3333
#
# Epoch 00077: val_loss did not improve from 0.61683
# Epoch 78/100
# 2/2 [==============================] - 2s 802ms/step - loss: 0.3288 - categorical_accuracy: 1.0000 - val_loss: 1.0575 - val_categorical_accuracy: 0.5000
#
# Epoch 00078: val_loss did not improve from 0.61683
# Epoch 79/100
# 2/2 [==============================] - 2s 784ms/step - loss: 0.3609 - categorical_accuracy: 1.0000 - val_loss: 0.8663 - val_categorical_accuracy: 0.6667
#
# Epoch 00079: val_loss did not improve from 0.61683
# Epoch 80/100
# 2/2 [==============================] - 2s 812ms/step - loss: 0.3701 - categorical_accuracy: 0.9670 - val_loss: 0.9580 - val_categorical_accuracy: 0.6667
#
# Epoch 00080: val_loss did not improve from 0.61683
# Epoch 81/100
# 2/2 [==============================] - 2s 784ms/step - loss: 0.3659 - categorical_accuracy: 0.9684 - val_loss: 0.8253 - val_categorical_accuracy: 0.6667
#
# Epoch 00081: val_loss did not improve from 0.61683
# Epoch 82/100
# 2/2 [==============================] - 2s 812ms/step - loss: 0.3882 - categorical_accuracy: 1.0000 - val_loss: 0.9370 - val_categorical_accuracy: 0.6667
#
# Epoch 00082: val_loss did not improve from 0.61683
# Epoch 83/100
# 2/2 [==============================] - 2s 801ms/step - loss: 0.3602 - categorical_accuracy: 0.9670 - val_loss: 0.8483 - val_categorical_accuracy: 0.5000
#
# Epoch 00083: val_loss did not improve from 0.61683
# Epoch 84/100
# 2/2 [==============================] - 2s 792ms/step - loss: 0.3203 - categorical_accuracy: 1.0000 - val_loss: 1.0329 - val_categorical_accuracy: 0.5000
#
# Epoch 00084: val_loss did not improve from 0.61683
# Epoch 85/100
# 2/2 [==============================] - 2s 816ms/step - loss: 0.4864 - categorical_accuracy: 0.9039 - val_loss: 1.0647 - val_categorical_accuracy: 0.6667
#
# Epoch 00085: val_loss did not improve from 0.61683
# Epoch 86/100
# 2/2 [==============================] - 2s 781ms/step - loss: 0.4040 - categorical_accuracy: 1.0000 - val_loss: 0.6863 - val_categorical_accuracy: 0.6667
#
# Epoch 00086: val_loss did not improve from 0.61683
# Epoch 87/100
# 2/2 [==============================] - 2s 805ms/step - loss: 0.3645 - categorical_accuracy: 1.0000 - val_loss: 1.0512 - val_categorical_accuracy: 0.8333
#
# Epoch 00087: val_loss did not improve from 0.61683
# Epoch 88/100
# 2/2 [==============================] - 2s 806ms/step - loss: 0.3289 - categorical_accuracy: 0.9354 - val_loss: 1.8627 - val_categorical_accuracy: 0.1667
#
# Epoch 00088: val_loss did not improve from 0.61683
# Epoch 89/100
# 2/2 [==============================] - 2s 801ms/step - loss: 0.2998 - categorical_accuracy: 1.0000 - val_loss: 1.0132 - val_categorical_accuracy: 0.6667
#
# Epoch 00089: val_loss did not improve from 0.61683
# Epoch 90/100
# 2/2 [==============================] - 2s 794ms/step - loss: 0.3592 - categorical_accuracy: 1.0000 - val_loss: 0.9081 - val_categorical_accuracy: 0.8333
#
# Epoch 00090: val_loss did not improve from 0.61683
# Epoch 91/100
# 2/2 [==============================] - 2s 804ms/step - loss: 0.3247 - categorical_accuracy: 1.0000 - val_loss: 0.7204 - val_categorical_accuracy: 0.8333
#
# Epoch 00091: val_loss did not improve from 0.61683
# Epoch 92/100
# 2/2 [==============================] - 2s 798ms/step - loss: 0.3472 - categorical_accuracy: 1.0000 - val_loss: 0.6499 - val_categorical_accuracy: 0.8333
#
# Epoch 00092: val_loss did not improve from 0.61683
# Epoch 93/100
# 2/2 [==============================] - 2s 812ms/step - loss: 0.3175 - categorical_accuracy: 1.0000 - val_loss: 1.2835 - val_categorical_accuracy: 0.3333
#
# Epoch 00093: val_loss did not improve from 0.61683
# Epoch 94/100
# 2/2 [==============================] - 2s 810ms/step - loss: 0.3213 - categorical_accuracy: 1.0000 - val_loss: 0.9656 - val_categorical_accuracy: 0.6667
#
# Epoch 00094: val_loss did not improve from 0.61683
# Epoch 95/100
# 2/2 [==============================] - 2s 796ms/step - loss: 0.4145 - categorical_accuracy: 0.9354 - val_loss: 1.7982 - val_categorical_accuracy: 0.3333
#
# Epoch 00095: val_loss did not improve from 0.61683
# Epoch 96/100
# 2/2 [==============================] - 2s 798ms/step - loss: 0.3226 - categorical_accuracy: 1.0000 - val_loss: 1.1814 - val_categorical_accuracy: 0.5000
#
# Epoch 00096: val_loss did not improve from 0.61683
# Epoch 97/100
# 2/2 [==============================] - 2s 801ms/step - loss: 0.3299 - categorical_accuracy: 1.0000 - val_loss: 1.2767 - val_categorical_accuracy: 0.5000
#
# Epoch 00097: val_loss did not improve from 0.61683
# Epoch 98/100
# 2/2 [==============================] - 2s 807ms/step - loss: 0.3139 - categorical_accuracy: 1.0000 - val_loss: 0.8437 - val_categorical_accuracy: 0.8333
#
# Epoch 00098: val_loss did not improve from 0.61683
# Epoch 99/100
# 2/2 [==============================] - 2s 806ms/step - loss: 0.3700 - categorical_accuracy: 0.9684 - val_loss: 1.1481 - val_categorical_accuracy: 0.3333
#
# Epoch 00099: val_loss did not improve from 0.61683
# Epoch 100/100
# 2/2 [==============================] - 2s 797ms/step - loss: 0.3098 - categorical_accuracy: 1.0000 - val_loss: 0.8236 - val_categorical_accuracy: 0.8333
#
# Epoch 00100: val_loss did not improve from 0.61683

# %% [markdown]
# #**Testing**

# %% [markdown]
# ## **Validation generator**

# %%
from sklearn.metrics import confusion_matrix, plot_confusion_matrix
from keras.models import load_model
loaded_model = buildModelFromDisk('./checkpoint.h5')


y_pred = loaded_model.predict_generator(validation_generator)
y_pred_argmax = [i.argmax() for i in y_pred]
y_true = validation_generator.classes

cm = confusion_matrix(y_true, y_pred_argmax)

print (cm)

total = sum(sum(cm))
hits = 0
for i in range(0,2):
  hits += cm[i][i]

print (hits / total)


plt.imshow(cm, cmap=plt.cm.Blues)
plt.xlabel("Predicted labels")
plt.ylabel("True labels")
plt.xticks([], [])
plt.yticks([], [])
plt.title('Confusion matrix ')
plt.colorbar()
plt.show()
# Out:
# [[2 0 0]
#  [0 2 0]
#  [1 0 1]]
# 0.6666666666666666

# %% [markdown]
# ##**/tests folder**

# %%
# SNIPPET TO LOAD DATA FROM DIRECTORY, FOR MANUAL WORK WITHOUT GENERATORS

import cv2
import glob
import numpy as np
import matplotlib.pyplot as plt
from keras.preprocessing import image

x_data = []
files = glob.glob (TEST_DIR + '/*.jpg') 

fig=plt.figure(figsize=(32, 32))
plotted_images = 1 

loaded_model = buildModelFromDisk('./checkpoint.h5')
predictions = []

for image_source in files:
    (image_original, image_tensor) = buildSampleFromDisk(image_source)

    fig.add_subplot(1, len(files), plotted_images) # subplot(rows, colums, currentIndexToPlot)
    plotted_images +=1
    
    image_label = image_source.split('/')[-1]
    plt.imshow(image_original)
    plt.xlabel(image_label)


    prediction = loaded_model.predict(image_tensor)
    print('prediction for ' + str(image_source))
    print(prediction)
    
    pred_label = prediction.argmax()

    if(pred_label == 0):
      print('calcium def')
    elif(pred_label == 1):
      print('healthy')
    else:
      print('iron def')
# Out:
# prediction for /content/drive/My Drive/CAI/iron_calcium/tests/iron3.jpg
# [[0.29547036 0.25391957 0.4506101 ]]
# iron def
# prediction for /content/drive/My Drive/CAI/iron_calcium/tests/iron2.jpg
# [[0.01673387 0.04432354 0.9389426 ]]
# iron def
# prediction for /content/drive/My Drive/CAI/iron_calcium/tests/iron1.jpg
# [[0.08711491 0.5951194  0.31776568]]
# healthy
# prediction for /content/drive/My Drive/CAI/iron_calcium/tests/cal2.jpg
# [[0.72017723 0.09139019 0.18843254]]
# calcium def
# prediction for /content/drive/My Drive/CAI/iron_calcium/tests/cal3.jpg
# [[0.83630466 0.06300414 0.10069124]]
# calcium def
# prediction for /content/drive/My Drive/CAI/iron_calcium/tests/cal1.jpg
# [[0.9181895  0.04656636 0.03524404]]
# calcium def
# prediction for /content/drive/My Drive/CAI/iron_calcium/tests/hp.jpg
# [[0.13448225 0.15003605 0.7154817 ]]
# iron def
# prediction for /content/drive/My Drive/CAI/iron_calcium/tests/hp1.jpg
# [[0.02014015 0.9474654  0.03239432]]
# healthy
# prediction for /content/drive/My Drive/CAI/iron_calcium/tests/hp3.jpg
# [[0.05070865 0.9357647  0.01352668]]
# healthy
