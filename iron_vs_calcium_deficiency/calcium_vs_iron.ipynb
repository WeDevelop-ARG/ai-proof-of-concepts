# %% [markdown]
# # **Mounting google drive file system**

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# !pip install keras==2.2.5
# !pip install tensorflow==1.15.2
# Out:
# Requirement already satisfied: tensorflow==1.15.2 in /usr/local/lib/python3.6/dist-packages (1.15.2)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.2) (0.9.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.2) (0.8.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.2) (1.1.0)
# Requirement already satisfied: tensorflow-estimator==1.15.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.2) (1.15.1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.2) (1.1.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.2) (1.12.1)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.2) (0.2.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.2) (1.12.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.2) (3.10.0)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.2) (1.0.8)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.2) (1.18.2)
# Requirement already satisfied: tensorboard<1.16.0,>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.2) (1.15.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.2) (1.27.2)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.2) (0.34.2)
# Requirement already satisfied: gast==0.2.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.2) (0.2.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.2) (3.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow==1.15.2) (46.0.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow==1.15.2) (2.10.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.2) (3.2.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.2) (1.0.0)

# %% [markdown]
# # **Setting up constants**

# %%
TRAINING_DIR = '/content/drive/My Drive/CAI/iron_calcium/training'
TEST_DIR = '/content/drive/My Drive/CAI/iron_calcium/tests'
SEED = 101
IMAGE_SIZE = 224
CHANNELS = 3 # red, green, blue

# %% [markdown]
# #**Checking Up data**

# %%
# SNIPPET TO LOAD DATA FROM DIRECTORY, FOR MANUAL WORK WITHOUT GENERATORS

import cv2
import glob
import numpy as np
import matplotlib.pyplot as plt

x_data = []
images_calcium = glob.glob (TRAINING_DIR + '/calcium/*.jpg')
images_iron = glob.glob (TRAINING_DIR + '/iron/*.jpg')

print ('calcium count ' + str(len(images_calcium)))
print ('iron count ' + str(len(images_iron)))
# Out:
# calcium count 8
# iron count 12

# %% [markdown]
# # **Cycle Learning Rate**

# %%
from keras.callbacks import Callback
from keras import backend as K
import numpy as np


class CyclicLR(Callback):
    """This callback implements a cyclical learning rate policy (CLR).
    The method cycles the learning rate between two boundaries with
    some constant frequency.
    # Arguments
        base_lr: initial learning rate which is the
            lower boundary in the cycle.
        max_lr: upper boundary in the cycle. Functionally,
            it defines the cycle amplitude (max_lr - base_lr).
            The lr at any cycle is the sum of base_lr
            and some scaling of the amplitude; therefore
            max_lr may not actually be reached depending on
            scaling function.
        step_size: number of training iterations per
            half cycle. Authors suggest setting step_size
            2-8 x training iterations in epoch.
        mode: one of {triangular, triangular2, exp_range}.
            Default 'triangular'.
            Values correspond to policies detailed above.
            If scale_fn is not None, this argument is ignored.
        gamma: constant in 'exp_range' scaling function:
            gamma**(cycle iterations)
        scale_fn: Custom scaling policy defined by a single
            argument lambda function, where
            0 <= scale_fn(x) <= 1 for all x >= 0.
            mode paramater is ignored
        scale_mode: {'cycle', 'iterations'}.
            Defines whether scale_fn is evaluated on
            cycle number or cycle iterations (training
            iterations since start of cycle). Default is 'cycle'.

    The amplitude of the cycle can be scaled on a per-iteration or
    per-cycle basis.
    This class has three built-in policies, as put forth in the paper.
    "triangular":
        A basic triangular cycle w/ no amplitude scaling.
    "triangular2":
        A basic triangular cycle that scales initial amplitude by half each cycle.
    "exp_range":
        A cycle that scales initial amplitude by gamma**(cycle iterations) at each
        cycle iteration.
    For more detail, please see paper.

    # Example for CIFAR-10 w/ batch size 100:
        ```python
            clr = CyclicLR(base_lr=0.001, max_lr=0.006,
                                step_size=2000., mode='triangular')
            model.fit(X_train, Y_train, callbacks=[clr])
        ```

    Class also supports custom scaling functions:
        ```python
            clr_fn = lambda x: 0.5*(1+np.sin(x*np.pi/2.))
            clr = CyclicLR(base_lr=0.001, max_lr=0.006,
                                step_size=2000., scale_fn=clr_fn,
                                scale_mode='cycle')
            model.fit(X_train, Y_train, callbacks=[clr])
        ```

    # References

      - [Cyclical Learning Rates for Training Neural Networks](
      https://arxiv.org/abs/1506.01186)
    """

    def __init__(
            self,
            base_lr=0.001,
            max_lr=0.006,
            step_size=2000.,
            mode='triangular',
            gamma=1.,
            scale_fn=None,
            scale_mode='cycle'):
        super(CyclicLR, self).__init__()

        if mode not in ['triangular', 'triangular2',
                        'exp_range']:
            raise KeyError("mode must be one of 'triangular', "
                           "'triangular2', or 'exp_range'")
        self.base_lr = base_lr
        self.max_lr = max_lr
        self.step_size = step_size
        self.mode = mode
        self.gamma = gamma
        if scale_fn is None:
            if self.mode == 'triangular':
                self.scale_fn = lambda x: 1.
                self.scale_mode = 'cycle'
            elif self.mode == 'triangular2':
                self.scale_fn = lambda x: 1 / (2.**(x - 1))
                self.scale_mode = 'cycle'
            elif self.mode == 'exp_range':
                self.scale_fn = lambda x: gamma ** x
                self.scale_mode = 'iterations'
        else:
            self.scale_fn = scale_fn
            self.scale_mode = scale_mode
        self.clr_iterations = 0.
        self.trn_iterations = 0.
        self.history = {}

        self._reset()

    def _reset(self, new_base_lr=None, new_max_lr=None,
               new_step_size=None):
        """Resets cycle iterations.
        Optional boundary/step size adjustment.
        """
        if new_base_lr is not None:
            self.base_lr = new_base_lr
        if new_max_lr is not None:
            self.max_lr = new_max_lr
        if new_step_size is not None:
            self.step_size = new_step_size
        self.clr_iterations = 0.

    def clr(self):
        cycle = np.floor(1 + self.clr_iterations / (2 * self.step_size))
        x = np.abs(self.clr_iterations / self.step_size - 2 * cycle + 1)
        if self.scale_mode == 'cycle':
            return self.base_lr + (self.max_lr - self.base_lr) * \
                np.maximum(0, (1 - x)) * self.scale_fn(cycle)
        else:
            return self.base_lr + (self.max_lr - self.base_lr) * \
                np.maximum(0, (1 - x)) * self.scale_fn(self.clr_iterations)

    def on_train_begin(self, logs={}):
        logs = logs or {}

        if self.clr_iterations == 0:
            K.set_value(self.model.optimizer.lr, self.base_lr)
        else:
            K.set_value(self.model.optimizer.lr, self.clr())

    def on_batch_end(self, epoch, logs=None):

        logs = logs or {}
        self.trn_iterations += 1
        self.clr_iterations += 1
        K.set_value(self.model.optimizer.lr, self.clr())

        self.history.setdefault(
            'lr', []).append(
            K.get_value(
                self.model.optimizer.lr))
        self.history.setdefault('iterations', []).append(self.trn_iterations)

        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        logs['lr'] = K.get_value(self.model.optimizer.lr)
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will switch to TensorFlow 2.x on the 27th of March, 2020.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %% [markdown]
# #**Adabound custom optimizer**

# %%
from keras import backend as K
from keras.optimizers import Optimizer


class AdaBound(Optimizer):
    """AdaBound optimizer.

    Default parameters follow those provided in the original paper.

    # Arguments
        lr: float >= 0. Learning rate.
        final_lr: float >= 0. Final learning rate.
        beta_1: float, 0 < beta < 1. Generally close to 1.
        beta_2: float, 0 < beta < 1. Generally close to 1.
        gamma: float >= 0. Convergence speed of the bound function.
        epsilon: float >= 0. Fuzz factor. If `None`, defaults to `K.epsilon()`.
        decay: float >= 0. Learning rate decay over each update.
        weight_decay: Weight decay weight.
        amsbound: boolean. Whether to apply the AMSBound variant of this
            algorithm.

    # References
        - [Adaptive Gradient Methods with Dynamic Bound of Learning Rate]
          (https://openreview.net/forum?id=Bkg3g2R9FX)
        - [Adam - A Method for Stochastic Optimization]
          (https://arxiv.org/abs/1412.6980v8)
        - [On the Convergence of Adam and Beyond]
          (https://openreview.net/forum?id=ryQu7f-RZ)
    """

    def __init__(self, lr=0.001, final_lr=0.1, beta_1=0.9, beta_2=0.999, gamma=1e-3,
                 epsilon=None, decay=0., amsbound=False, weight_decay=0.0, **kwargs):
        super(AdaBound, self).__init__(**kwargs)

        if not 0. <= gamma <= 1.:
            raise ValueError("Invalid `gamma` parameter. Must lie in [0, 1] range.")

        with K.name_scope(self.__class__.__name__):
            self.iterations = K.variable(0, dtype='int64', name='iterations')
            self.lr = K.variable(lr, name='lr')
            self.beta_1 = K.variable(beta_1, name='beta_1')
            self.beta_2 = K.variable(beta_2, name='beta_2')
            self.decay = K.variable(decay, name='decay')

        self.final_lr = final_lr
        self.gamma = gamma

        if epsilon is None:
            epsilon = K.epsilon()
        self.epsilon = epsilon
        self.initial_decay = decay
        self.amsbound = amsbound

        self.weight_decay = float(weight_decay)
        self.base_lr = float(lr)

    def get_updates(self, loss, params):
        grads = self.get_gradients(loss, params)
        self.updates = [K.update_add(self.iterations, 1)]

        lr = self.lr
        if self.initial_decay > 0:
            lr = lr * (1. / (1. + self.decay * K.cast(self.iterations,
                                                      K.dtype(self.decay))))

        t = K.cast(self.iterations, K.floatx()) + 1

        # Applies bounds on actual learning rate
        step_size = lr * (K.sqrt(1. - K.pow(self.beta_2, t)) /
                          (1. - K.pow(self.beta_1, t)))

        final_lr = self.final_lr * lr / self.base_lr
        lower_bound = final_lr * (1. - 1. / (self.gamma * t + 1.))
        upper_bound = final_lr * (1. + 1. / (self.gamma * t))

        ms = [K.zeros(K.int_shape(p), dtype=K.dtype(p)) for p in params]
        vs = [K.zeros(K.int_shape(p), dtype=K.dtype(p)) for p in params]
        if self.amsbound:
            vhats = [K.zeros(K.int_shape(p), dtype=K.dtype(p)) for p in params]
        else:
            vhats = [K.zeros(1) for _ in params]
        self.weights = [self.iterations] + ms + vs + vhats

        for p, g, m, v, vhat in zip(params, grads, ms, vs, vhats):
            # apply weight decay
            if self.weight_decay != 0.:
                g += self.weight_decay * K.stop_gradient(p)

            m_t = (self.beta_1 * m) + (1. - self.beta_1) * g
            v_t = (self.beta_2 * v) + (1. - self.beta_2) * K.square(g)

            if self.amsbound:
                vhat_t = K.maximum(vhat, v_t)
                denom = (K.sqrt(vhat_t) + self.epsilon)
                self.updates.append(K.update(vhat, vhat_t))
            else:
                denom = (K.sqrt(v_t) + self.epsilon)

            # Compute the bounds
            step_size_p = step_size * K.ones_like(denom)
            step_size_p_bound = step_size_p / denom
            bounded_lr_t = m_t * K.minimum(K.maximum(step_size_p_bound,
                                                     lower_bound), upper_bound)

            p_t = p - bounded_lr_t

            self.updates.append(K.update(m, m_t))
            self.updates.append(K.update(v, v_t))
            new_p = p_t

            # Apply constraints.
            if getattr(p, 'constraint', None) is not None:
                new_p = p.constraint(new_p)

            self.updates.append(K.update(p, new_p))
        return self.updates

    def get_config(self):
        config = {'lr': float(K.get_value(self.lr)),
                  'final_lr': float(self.final_lr),
                  'beta_1': float(K.get_value(self.beta_1)),
                  'beta_2': float(K.get_value(self.beta_2)),
                  'gamma': float(self.gamma),
                  'decay': float(K.get_value(self.decay)),
                  'epsilon': self.epsilon,
                  'weight_decay': self.weight_decay,
                  'amsbound': self.amsbound}
        base_config = super(AdaBound, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

# %% [markdown]
# # **Function definitions**
#
#
#
# *   buildModel
# *   buildModelFromDisk
# *   getHyperparameters
# *   getTrainingHyperparameters
# *   buildSampleFromDisk

# %% [markdown]
# ## **Hyperparameters**

# %%
'''
  Hyperparameters used to compile the model
'''

from keras.optimizers import RMSprop, Adadelta, Adam, SGD

def getHyperparameters():
  OPTIMIZER = AdaBound(1e-2, 1e-4)
  LOSS = 'categorical_crossentropy'
  METRICS = ['categorical_accuracy']

  return (LOSS, OPTIMIZER, METRICS)

# %% [markdown]
# ## **Training parameters**

# %%
'''
  Hyperparameters that are used only for training phase, e.g, number of epochs,
  batch size.
'''

from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping

def getTrainingHyperparameters():
  reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=45, verbose=1) 
  early_stop = EarlyStopping(patience=30, restore_best_weights=True)
  model_checkpoint = ModelCheckpoint('./checkpoint.h5', monitor='val_loss', save_best_only=True, verbose=1)
  cycle_learning_rate = CyclicLR(1e-7, 1e-1, step_size=100, mode='triangular2') 
  CALLBACK = [
    reduce_lr,
    model_checkpoint
  ]

  BATCH_SIZE = 16
  EPOCHS = 100

  return (EPOCHS, BATCH_SIZE, CALLBACK)

# %% [markdown]
# ##**buildModel**

# %%
'''
  Model architecture definiton, including layers, initializers, activations and more
'''

from keras.layers import Dense, Input, Conv2D, Flatten, MaxPool2D, Dropout, GlobalAveragePooling2D, BatchNormalization, LeakyReLU
from keras.models import Model
from keras.initializers import Constant
from keras.regularizers import l2

kernel_regularizer = l2(0.1)
activity_regularizer = l2(0.001)

def buildModel():
  i = Input(shape=(IMAGE_SIZE, IMAGE_SIZE, CHANNELS))
  d = Conv2D(filters=16, kernel_size=(7,7), kernel_initializer='glorot_uniform', bias_initializer=Constant(0.1))(i)
  d = LeakyReLU(0.01)(d)
  d = BatchNormalization()(d)
  d = Conv2D(filters=32, kernel_size=(7,7) , kernel_initializer='glorot_uniform', bias_initializer=Constant(0.1))(d)
  d = LeakyReLU(0.01)(d)
  d = MaxPool2D(pool_size=(2,2))(d)
  d = BatchNormalization()(d)
  d = Conv2D(filters=64, kernel_size=(5,5), kernel_initializer='glorot_uniform', bias_initializer=Constant(0.1))(d)
  d = LeakyReLU(0.01)(d)
  d = GlobalAveragePooling2D()(d)
  d = BatchNormalization()(d)
  d = Dense(64, activation='relu', kernel_initializer='glorot_uniform', bias_initializer=Constant(0.1), activity_regularizer=activity_regularizer)(d)
  d = Dropout(0.30)(d)
  d = Dense(2, activation='softmax', kernel_initializer='glorot_uniform', bias_initializer=Constant(0.1))(d)

  model = Model(inputs=i, outputs=d)

  (LOSS, OPTIMIZER, METRICS) = getHyperparameters()

  model.compile(loss=LOSS, optimizer=OPTIMIZER, metrics=METRICS)

  return model

# %% [markdown]
# ##**buildModelFromDisk**

# %%
from keras.models import load_model

def buildModelFromDisk(path='model.h5'):
  model = load_model(path, compile=False)

  return model

# %% [markdown]
# ##**buildSampleFromDisk**

# %%
import numpy as np
from keras.preprocessing import image

def buildSampleFromDisk(img_path: str):
  original_test_image = image.load_img(img_path, target_size=(IMAGE_SIZE,IMAGE_SIZE))
    
  test_image = image.img_to_array(original_test_image)

  test_tensor = np.reshape(test_image, (1, IMAGE_SIZE, IMAGE_SIZE, CHANNELS))

  test_tensor = test_tensor / 255

  return (original_test_image, test_tensor)

# %% [markdown]
# ## **changeImageColorSpaceToHSV**

# %%
import cv2
import numpy as np

def changeImageColorSpaceToHSV(image):
    image = np.array(image)
    hsv_image = cv2.cvtColor(image,cv2.COLOR_RGB2HSV)

    return hsv_image

# %% [markdown]
# # **Training**

# %%
(LOSS, OPTIMIZER, METRICS) = getHyperparameters()
(EPOCHS, BATCH_SIZE, CALLBACKS) = getTrainingHyperparameters()

# %% [markdown]
# ## **Generators**

# %%
from keras.preprocessing.image import ImageDataGenerator
# Create data generators to load images from disk and do data augmentation


data_generator = ImageDataGenerator(
  rescale=1./255,
  validation_split=0.2,
  rotation_range = 10,
  width_shift_range=0.2
)

train_generator = data_generator.flow_from_directory(
  TRAINING_DIR,
  target_size=(IMAGE_SIZE, IMAGE_SIZE),
  shuffle=True,
  seed=SEED,  
  class_mode='categorical',
  batch_size=BATCH_SIZE,
  subset="training"
)

validation_generator = data_generator.flow_from_directory(
  TRAINING_DIR,
  target_size=(IMAGE_SIZE, IMAGE_SIZE),
  shuffle=False,
  seed=SEED,
  class_mode='categorical',
  batch_size=BATCH_SIZE,
  subset="validation"
)
# Out:
# Found 21 images belonging to 2 classes.
# Found 4 images belonging to 2 classes.

# %% [markdown]
# ##**Fit**

# %%
import matplotlib.pyplot as plt
import numpy as np 
from keras.metrics import categorical_crossentropy, categorical_accuracy

model = buildModel()

model.summary()

history = model.fit_generator(
  train_generator,
  epochs=EPOCHS,
  validation_data=validation_generator,
  shuffle=True,
  callbacks=CALLBACKS
)

model.save('./model.h5')

# Plot step by step movements of the accuracy metric

plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.
#
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 218, 218, 16)      2368
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 218, 218, 16)      0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 218, 218, 16)      64
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 212, 212, 32)      25120
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 212, 212, 32)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 106, 106, 32)      0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 106, 106, 32)      128
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 102, 102, 64)      51264
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 102, 102, 64)      0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 64)                0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64)                256
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 83,490
# Trainable params: 83,266
# Non-trainable params: 224
# _________________________________________________________________
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/250
# 1/1 [==============================] - 20s 20s/step - loss: 1.6022 - categorical_accuracy: 0.4762 - val_loss: 1.8349 - val_categorical_accuracy: 0.5000
#
# Epoch 00001: val_loss improved from inf to 1.83488, saving model to ./checkpoint.h5
# Epoch 2/250
# 1/1 [==============================] - 8s 8s/step - loss: 1.2097 - categorical_accuracy: 0.7619 - val_loss: 1.5874 - val_categorical_accuracy: 0.5000
#
# Epoch 00002: val_loss improved from 1.83488 to 1.58745, saving model to ./checkpoint.h5
# Epoch 3/250
# 1/1 [==============================] - 8s 8s/step - loss: 1.2306 - categorical_accuracy: 0.7619 - val_loss: 1.6559 - val_categorical_accuracy: 0.5000
#
# Epoch 00003: val_loss did not improve from 1.58745
# Epoch 4/250
# 1/1 [==============================] - 8s 8s/step - loss: 1.1364 - categorical_accuracy: 0.7143 - val_loss: 1.5333 - val_categorical_accuracy: 0.2500
#
# Epoch 00004: val_loss improved from 1.58745 to 1.53334, saving model to ./checkpoint.h5
# Epoch 5/250
# 1/1 [==============================] - 8s 8s/step - loss: 0.9188 - categorical_accuracy: 0.8571 - val_loss: 1.1837 - val_categorical_accuracy: 0.5000
#
# Epoch 00005: val_loss improved from 1.53334 to 1.18366, saving model to ./checkpoint.h5
# Epoch 6/250
# 1/1 [==============================] - 8s 8s/step - loss: 0.8115 - categorical_accuracy: 0.8571 - val_loss: 1.1398 - val_categorical_accuracy: 0.5000
#
# Epoch 00006: val_loss improved from 1.18366 to 1.13976, saving model to ./checkpoint.h5
# Epoch 7/250
# 1/1 [==============================] - 8s 8s/step - loss: 0.8759 - categorical_accuracy: 0.8095 - val_loss: 0.9973 - val_categorical_accuracy: 0.7500
#
# Epoch 00007: val_loss improved from 1.13976 to 0.99728, saving model to ./checkpoint.h5
# Epoch 8/250
# 1/1 [==============================] - 8s 8s/step - loss: 0.7924 - categorical_accuracy: 0.8571 - val_loss: 0.9675 - val_categorical_accuracy: 0.5000
#
# Epoch 00008: val_loss improved from 0.99728 to 0.96747, saving model to ./checkpoint.h5
# Epoch 9/250
# 1/1 [==============================] - 8s 8s/step - loss: 0.8691 - categorical_accuracy: 0.8571 - val_loss: 0.9824 - val_categorical_accuracy: 0.5000
#
# Epoch 00009: val_loss did not improve from 0.96747
# Epoch 10/250
# 1/1 [==============================] - 8s 8s/step - loss: 0.7191 - categorical_accuracy: 1.0000 - val_loss: 1.0002 - val_categorical_accuracy: 0.2500
#
# Epoch 00010: val_loss did not improve from 0.96747
# Epoch 11/250
# 1/1 [==============================] - 8s 8s/step - loss: 0.6898 - categorical_accuracy: 0.9048 - val_loss: 0.8122 - val_categorical_accuracy: 0.5000
#
# Epoch 00011: val_loss improved from 0.96747 to 0.81218, saving model to ./checkpoint.h5
# Epoch 12/250
# 1/1 [==============================] - 8s 8s/step - loss: 0.6952 - categorical_accuracy: 1.0000 - val_loss: 1.0678 - val_categorical_accuracy: 0.5000
#
# Epoch 00012: val_loss did not improve from 0.81218
# Epoch 13/250
# 1/1 [==============================] - 8s 8s/step - loss: 0.6286 - categorical_accuracy: 1.0000 - val_loss: 0.8873 - val_categorical_accuracy: 0.5000
#
# Epoch 00013: val_loss did not improve from 0.81218
# Epoch 14/250
# 1/1 [==============================] - 8s 8s/step - loss: 0.6584 - categorical_accuracy: 0.9048 - val_loss: 0.9532 - val_categorical_accuracy: 0.5000
#
# Epoch 00014: val_loss did not improve from 0.81218
# Epoch 15/250
# 1/1 [==============================] - 8s 8s/step - loss: 0.6706 - categorical_accuracy: 0.9524 - val_loss: 0.9648 - val_categorical_accuracy: 0.2500
#
# Epoch 00015: val_loss did not improve from 0.81218
# Epoch 16/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.5958 - categorical_accuracy: 0.9524 - val_loss: 1.2222 - val_categorical_accuracy: 0.2500
#
# Epoch 00016: val_loss did not improve from 0.81218
# Epoch 17/250
# 1/1 [==============================] - 8s 8s/step - loss: 0.6639 - categorical_accuracy: 0.9048 - val_loss: 1.2350 - val_categorical_accuracy: 0.2500
#
# Epoch 00017: val_loss did not improve from 0.81218
# Epoch 18/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.6262 - categorical_accuracy: 0.9524 - val_loss: 1.3494 - val_categorical_accuracy: 0.2500
#
# Epoch 00018: val_loss did not improve from 0.81218
# Epoch 19/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.6624 - categorical_accuracy: 0.9524 - val_loss: 1.0997 - val_categorical_accuracy: 0.2500
#
# Epoch 00019: val_loss did not improve from 0.81218
# Epoch 20/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.6002 - categorical_accuracy: 0.9048 - val_loss: 1.2026 - val_categorical_accuracy: 0.2500
#
# Epoch 00020: val_loss did not improve from 0.81218
# Epoch 21/250
# 1/1 [==============================] - 8s 8s/step - loss: 0.6213 - categorical_accuracy: 0.9048 - val_loss: 0.9202 - val_categorical_accuracy: 0.5000
#
# Epoch 00021: val_loss did not improve from 0.81218
# Epoch 22/250
# 1/1 [==============================] - 8s 8s/step - loss: 0.5831 - categorical_accuracy: 1.0000 - val_loss: 0.9004 - val_categorical_accuracy: 0.5000
#
# Epoch 00022: val_loss did not improve from 0.81218
# Epoch 23/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.5890 - categorical_accuracy: 0.9524 - val_loss: 0.9007 - val_categorical_accuracy: 0.5000
#
# Epoch 00023: val_loss did not improve from 0.81218
# Epoch 24/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.6107 - categorical_accuracy: 0.9524 - val_loss: 0.8106 - val_categorical_accuracy: 0.7500
#
# Epoch 00024: val_loss improved from 0.81218 to 0.81058, saving model to ./checkpoint.h5
# Epoch 25/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4927 - categorical_accuracy: 0.9524 - val_loss: 0.8914 - val_categorical_accuracy: 0.5000
#
# Epoch 00025: val_loss did not improve from 0.81058
# Epoch 26/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.5494 - categorical_accuracy: 1.0000 - val_loss: 0.7453 - val_categorical_accuracy: 0.5000
#
# Epoch 00026: val_loss improved from 0.81058 to 0.74529, saving model to ./checkpoint.h5
# Epoch 27/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.5532 - categorical_accuracy: 1.0000 - val_loss: 0.7866 - val_categorical_accuracy: 0.5000
#
# Epoch 00027: val_loss did not improve from 0.74529
# Epoch 28/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.6305 - categorical_accuracy: 0.9048 - val_loss: 0.8499 - val_categorical_accuracy: 0.5000
#
# Epoch 00028: val_loss did not improve from 0.74529
# Epoch 29/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.5365 - categorical_accuracy: 1.0000 - val_loss: 0.8297 - val_categorical_accuracy: 0.5000
#
# Epoch 00029: val_loss did not improve from 0.74529
# Epoch 30/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.5861 - categorical_accuracy: 0.9524 - val_loss: 1.0055 - val_categorical_accuracy: 0.5000
#
# Epoch 00030: val_loss did not improve from 0.74529
# Epoch 31/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.5740 - categorical_accuracy: 0.9524 - val_loss: 0.8511 - val_categorical_accuracy: 0.5000
#
# Epoch 00031: val_loss did not improve from 0.74529
# Epoch 32/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.5134 - categorical_accuracy: 1.0000 - val_loss: 0.8003 - val_categorical_accuracy: 0.7500
#
# Epoch 00032: val_loss did not improve from 0.74529
# Epoch 33/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.5001 - categorical_accuracy: 1.0000 - val_loss: 0.8237 - val_categorical_accuracy: 0.5000
#
# Epoch 00033: val_loss did not improve from 0.74529
# Epoch 34/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4920 - categorical_accuracy: 1.0000 - val_loss: 0.9709 - val_categorical_accuracy: 0.5000
#
# Epoch 00034: val_loss did not improve from 0.74529
# Epoch 35/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.5714 - categorical_accuracy: 1.0000 - val_loss: 0.8346 - val_categorical_accuracy: 0.7500
#
# Epoch 00035: val_loss did not improve from 0.74529
# Epoch 36/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.5183 - categorical_accuracy: 1.0000 - val_loss: 0.7407 - val_categorical_accuracy: 0.7500
#
# Epoch 00036: val_loss improved from 0.74529 to 0.74066, saving model to ./checkpoint.h5
# Epoch 37/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4648 - categorical_accuracy: 1.0000 - val_loss: 0.7136 - val_categorical_accuracy: 0.7500
#
# Epoch 00037: val_loss improved from 0.74066 to 0.71359, saving model to ./checkpoint.h5
# Epoch 38/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4954 - categorical_accuracy: 1.0000 - val_loss: 0.7396 - val_categorical_accuracy: 0.7500
#
# Epoch 00038: val_loss did not improve from 0.71359
# Epoch 39/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.5141 - categorical_accuracy: 1.0000 - val_loss: 0.7833 - val_categorical_accuracy: 0.5000
#
# Epoch 00039: val_loss did not improve from 0.71359
# Epoch 40/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.5050 - categorical_accuracy: 1.0000 - val_loss: 0.6955 - val_categorical_accuracy: 0.7500
#
# Epoch 00040: val_loss improved from 0.71359 to 0.69548, saving model to ./checkpoint.h5
# Epoch 41/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4927 - categorical_accuracy: 1.0000 - val_loss: 0.8129 - val_categorical_accuracy: 0.5000
#
# Epoch 00041: val_loss did not improve from 0.69548
# Epoch 42/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4698 - categorical_accuracy: 1.0000 - val_loss: 0.8243 - val_categorical_accuracy: 0.7500
#
# Epoch 00042: val_loss did not improve from 0.69548
# Epoch 43/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.5129 - categorical_accuracy: 1.0000 - val_loss: 1.0011 - val_categorical_accuracy: 0.5000
#
# Epoch 00043: val_loss did not improve from 0.69548
# Epoch 44/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4599 - categorical_accuracy: 1.0000 - val_loss: 0.9166 - val_categorical_accuracy: 0.2500
#
# Epoch 00044: val_loss did not improve from 0.69548
# Epoch 45/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4542 - categorical_accuracy: 1.0000 - val_loss: 0.7851 - val_categorical_accuracy: 0.5000
#
# Epoch 00045: val_loss did not improve from 0.69548
# Epoch 46/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4591 - categorical_accuracy: 1.0000 - val_loss: 0.9357 - val_categorical_accuracy: 0.2500
#
# Epoch 00046: val_loss did not improve from 0.69548
# Epoch 47/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4697 - categorical_accuracy: 1.0000 - val_loss: 0.8784 - val_categorical_accuracy: 0.2500
#
# Epoch 00047: val_loss did not improve from 0.69548
# Epoch 48/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4598 - categorical_accuracy: 1.0000 - val_loss: 0.6678 - val_categorical_accuracy: 0.7500
#
# Epoch 00048: val_loss improved from 0.69548 to 0.66780, saving model to ./checkpoint.h5
# Epoch 49/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4628 - categorical_accuracy: 1.0000 - val_loss: 0.8993 - val_categorical_accuracy: 0.2500
#
# Epoch 00049: val_loss did not improve from 0.66780
# Epoch 50/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4324 - categorical_accuracy: 1.0000 - val_loss: 0.6415 - val_categorical_accuracy: 0.7500
#
# Epoch 00050: val_loss improved from 0.66780 to 0.64151, saving model to ./checkpoint.h5
# Epoch 51/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4480 - categorical_accuracy: 1.0000 - val_loss: 0.6616 - val_categorical_accuracy: 0.5000
#
# Epoch 00051: val_loss did not improve from 0.64151
# Epoch 52/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4663 - categorical_accuracy: 1.0000 - val_loss: 0.7707 - val_categorical_accuracy: 0.7500
#
# Epoch 00052: val_loss did not improve from 0.64151
# Epoch 53/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4660 - categorical_accuracy: 1.0000 - val_loss: 0.7887 - val_categorical_accuracy: 0.5000
#
# Epoch 00053: val_loss did not improve from 0.64151
# Epoch 54/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4866 - categorical_accuracy: 0.9524 - val_loss: 0.8210 - val_categorical_accuracy: 0.5000
#
# Epoch 00054: val_loss did not improve from 0.64151
# Epoch 55/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4508 - categorical_accuracy: 1.0000 - val_loss: 0.7191 - val_categorical_accuracy: 0.7500
#
# Epoch 00055: val_loss did not improve from 0.64151
# Epoch 56/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4481 - categorical_accuracy: 1.0000 - val_loss: 0.7726 - val_categorical_accuracy: 0.5000
#
# Epoch 00056: val_loss did not improve from 0.64151
# Epoch 57/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4527 - categorical_accuracy: 1.0000 - val_loss: 0.7585 - val_categorical_accuracy: 0.7500
#
# Epoch 00057: val_loss did not improve from 0.64151
# Epoch 58/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4327 - categorical_accuracy: 1.0000 - val_loss: 0.7580 - val_categorical_accuracy: 0.5000
#
# Epoch 00058: val_loss did not improve from 0.64151
# Epoch 59/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4376 - categorical_accuracy: 1.0000 - val_loss: 0.7027 - val_categorical_accuracy: 0.5000
#
# Epoch 00059: val_loss did not improve from 0.64151
# Epoch 60/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.5124 - categorical_accuracy: 1.0000 - val_loss: 0.8121 - val_categorical_accuracy: 0.5000
#
# Epoch 00060: val_loss did not improve from 0.64151
# Epoch 61/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4821 - categorical_accuracy: 0.9524 - val_loss: 0.7652 - val_categorical_accuracy: 0.5000
#
# Epoch 00061: val_loss did not improve from 0.64151
# Epoch 62/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4502 - categorical_accuracy: 1.0000 - val_loss: 0.9178 - val_categorical_accuracy: 0.2500
#
# Epoch 00062: val_loss did not improve from 0.64151
# Epoch 63/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4291 - categorical_accuracy: 1.0000 - val_loss: 0.6797 - val_categorical_accuracy: 0.7500
#
# Epoch 00063: val_loss did not improve from 0.64151
# Epoch 64/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.5282 - categorical_accuracy: 0.9524 - val_loss: 0.8861 - val_categorical_accuracy: 0.5000
#
# Epoch 00064: val_loss did not improve from 0.64151
# Epoch 65/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4209 - categorical_accuracy: 1.0000 - val_loss: 0.8655 - val_categorical_accuracy: 0.5000
#
# Epoch 00065: val_loss did not improve from 0.64151
# Epoch 66/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4313 - categorical_accuracy: 1.0000 - val_loss: 0.7245 - val_categorical_accuracy: 0.7500
#
# Epoch 00066: val_loss did not improve from 0.64151
# Epoch 67/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4281 - categorical_accuracy: 1.0000 - val_loss: 0.8347 - val_categorical_accuracy: 0.5000
#
# Epoch 00067: val_loss did not improve from 0.64151
# Epoch 68/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4663 - categorical_accuracy: 1.0000 - val_loss: 0.7504 - val_categorical_accuracy: 0.7500
#
# Epoch 00068: val_loss did not improve from 0.64151
# Epoch 69/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4227 - categorical_accuracy: 1.0000 - val_loss: 0.8923 - val_categorical_accuracy: 0.5000
#
# Epoch 00069: val_loss did not improve from 0.64151
# Epoch 70/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4629 - categorical_accuracy: 1.0000 - val_loss: 0.6578 - val_categorical_accuracy: 0.7500
#
# Epoch 00070: val_loss did not improve from 0.64151
# Epoch 71/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4284 - categorical_accuracy: 1.0000 - val_loss: 0.6853 - val_categorical_accuracy: 0.7500
#
# Epoch 00071: val_loss did not improve from 0.64151
# Epoch 72/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4566 - categorical_accuracy: 1.0000 - val_loss: 0.7402 - val_categorical_accuracy: 0.5000
#
# Epoch 00072: val_loss did not improve from 0.64151
# Epoch 73/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4633 - categorical_accuracy: 0.9524 - val_loss: 0.7716 - val_categorical_accuracy: 0.5000
#
# Epoch 00073: val_loss did not improve from 0.64151
# Epoch 74/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4473 - categorical_accuracy: 0.9524 - val_loss: 0.8731 - val_categorical_accuracy: 0.5000
#
# Epoch 00074: val_loss did not improve from 0.64151
# Epoch 75/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4329 - categorical_accuracy: 1.0000 - val_loss: 0.9325 - val_categorical_accuracy: 0.5000
#
# Epoch 00075: val_loss did not improve from 0.64151
# Epoch 76/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4388 - categorical_accuracy: 1.0000 - val_loss: 0.8678 - val_categorical_accuracy: 0.5000
#
# Epoch 00076: val_loss did not improve from 0.64151
# Epoch 77/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4587 - categorical_accuracy: 1.0000 - val_loss: 0.8441 - val_categorical_accuracy: 0.2500
#
# Epoch 00077: val_loss did not improve from 0.64151
# Epoch 78/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4230 - categorical_accuracy: 1.0000 - val_loss: 0.9302 - val_categorical_accuracy: 0.5000
#
# Epoch 00078: val_loss did not improve from 0.64151
# Epoch 79/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4359 - categorical_accuracy: 1.0000 - val_loss: 0.6679 - val_categorical_accuracy: 0.7500
#
# Epoch 00079: val_loss did not improve from 0.64151
# Epoch 80/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4041 - categorical_accuracy: 1.0000 - val_loss: 0.6440 - val_categorical_accuracy: 0.7500
#
# Epoch 00080: val_loss did not improve from 0.64151
# Epoch 81/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4377 - categorical_accuracy: 1.0000 - val_loss: 0.6754 - val_categorical_accuracy: 0.7500
#
# Epoch 00081: val_loss did not improve from 0.64151
# Epoch 82/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3697 - categorical_accuracy: 1.0000 - val_loss: 0.6306 - val_categorical_accuracy: 0.7500
#
# Epoch 00082: val_loss improved from 0.64151 to 0.63059, saving model to ./checkpoint.h5
# Epoch 83/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4340 - categorical_accuracy: 1.0000 - val_loss: 0.7682 - val_categorical_accuracy: 0.7500
#
# Epoch 00083: val_loss did not improve from 0.63059
# Epoch 84/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4145 - categorical_accuracy: 1.0000 - val_loss: 0.7789 - val_categorical_accuracy: 0.7500
#
# Epoch 00084: val_loss did not improve from 0.63059
# Epoch 85/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4208 - categorical_accuracy: 1.0000 - val_loss: 0.7119 - val_categorical_accuracy: 0.7500
#
# Epoch 00085: val_loss did not improve from 0.63059
# Epoch 86/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4054 - categorical_accuracy: 1.0000 - val_loss: 0.8178 - val_categorical_accuracy: 0.2500
#
# Epoch 00086: val_loss did not improve from 0.63059
# Epoch 87/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4211 - categorical_accuracy: 1.0000 - val_loss: 0.8625 - val_categorical_accuracy: 0.2500
#
# Epoch 00087: val_loss did not improve from 0.63059
# Epoch 88/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4477 - categorical_accuracy: 0.9524 - val_loss: 0.9397 - val_categorical_accuracy: 0.2500
#
# Epoch 00088: val_loss did not improve from 0.63059
# Epoch 89/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3798 - categorical_accuracy: 1.0000 - val_loss: 0.9193 - val_categorical_accuracy: 0.2500
#
# Epoch 00089: val_loss did not improve from 0.63059
# Epoch 90/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4028 - categorical_accuracy: 1.0000 - val_loss: 1.0760 - val_categorical_accuracy: 0.2500
#
# Epoch 00090: val_loss did not improve from 0.63059
# Epoch 91/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4222 - categorical_accuracy: 1.0000 - val_loss: 1.0817 - val_categorical_accuracy: 0.2500
#
# Epoch 00091: val_loss did not improve from 0.63059
# Epoch 92/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4355 - categorical_accuracy: 1.0000 - val_loss: 1.0060 - val_categorical_accuracy: 0.2500
#
# Epoch 00092: val_loss did not improve from 0.63059
# Epoch 93/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3914 - categorical_accuracy: 1.0000 - val_loss: 1.0132 - val_categorical_accuracy: 0.2500
#
# Epoch 00093: val_loss did not improve from 0.63059
# Epoch 94/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3956 - categorical_accuracy: 1.0000 - val_loss: 0.9894 - val_categorical_accuracy: 0.2500
#
# Epoch 00094: val_loss did not improve from 0.63059
# Epoch 95/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4238 - categorical_accuracy: 1.0000 - val_loss: 0.7211 - val_categorical_accuracy: 0.5000
#
# Epoch 00095: val_loss did not improve from 0.63059
# Epoch 96/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4203 - categorical_accuracy: 1.0000 - val_loss: 0.8596 - val_categorical_accuracy: 0.2500
#
# Epoch 00096: val_loss did not improve from 0.63059
# Epoch 97/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4149 - categorical_accuracy: 1.0000 - val_loss: 0.7353 - val_categorical_accuracy: 0.5000
#
# Epoch 00097: val_loss did not improve from 0.63059
# Epoch 98/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4069 - categorical_accuracy: 1.0000 - val_loss: 0.7637 - val_categorical_accuracy: 0.7500
#
# Epoch 00098: val_loss did not improve from 0.63059
# Epoch 99/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4203 - categorical_accuracy: 1.0000 - val_loss: 0.8184 - val_categorical_accuracy: 0.7500
#
# Epoch 00099: val_loss did not improve from 0.63059
# Epoch 100/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4219 - categorical_accuracy: 1.0000 - val_loss: 0.7969 - val_categorical_accuracy: 0.5000
#
# Epoch 00100: val_loss did not improve from 0.63059
# Epoch 101/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4280 - categorical_accuracy: 1.0000 - val_loss: 0.7532 - val_categorical_accuracy: 0.7500
#
# Epoch 00101: val_loss did not improve from 0.63059
# Epoch 102/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4180 - categorical_accuracy: 1.0000 - val_loss: 0.8225 - val_categorical_accuracy: 0.5000
#
# Epoch 00102: val_loss did not improve from 0.63059
# Epoch 103/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4054 - categorical_accuracy: 1.0000 - val_loss: 0.6639 - val_categorical_accuracy: 0.7500
#
# Epoch 00103: val_loss did not improve from 0.63059
# Epoch 104/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4229 - categorical_accuracy: 1.0000 - val_loss: 0.8143 - val_categorical_accuracy: 0.5000
#
# Epoch 00104: val_loss did not improve from 0.63059
# Epoch 105/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3839 - categorical_accuracy: 1.0000 - val_loss: 0.8010 - val_categorical_accuracy: 0.5000
#
# Epoch 00105: val_loss did not improve from 0.63059
# Epoch 106/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4009 - categorical_accuracy: 1.0000 - val_loss: 0.8885 - val_categorical_accuracy: 0.2500
#
# Epoch 00106: val_loss did not improve from 0.63059
# Epoch 107/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3727 - categorical_accuracy: 1.0000 - val_loss: 1.0937 - val_categorical_accuracy: 0.2500
#
# Epoch 00107: val_loss did not improve from 0.63059
# Epoch 108/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3815 - categorical_accuracy: 1.0000 - val_loss: 0.8449 - val_categorical_accuracy: 0.2500
#
# Epoch 00108: val_loss did not improve from 0.63059
# Epoch 109/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4105 - categorical_accuracy: 1.0000 - val_loss: 0.9550 - val_categorical_accuracy: 0.2500
#
# Epoch 00109: val_loss did not improve from 0.63059
# Epoch 110/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3863 - categorical_accuracy: 1.0000 - val_loss: 0.8232 - val_categorical_accuracy: 0.2500
#
# Epoch 00110: val_loss did not improve from 0.63059
# Epoch 111/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3877 - categorical_accuracy: 1.0000 - val_loss: 0.8752 - val_categorical_accuracy: 0.2500
#
# Epoch 00111: val_loss did not improve from 0.63059
# Epoch 112/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4199 - categorical_accuracy: 1.0000 - val_loss: 1.0061 - val_categorical_accuracy: 0.2500
#
# Epoch 00112: val_loss did not improve from 0.63059
# Epoch 113/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4149 - categorical_accuracy: 1.0000 - val_loss: 1.0958 - val_categorical_accuracy: 0.2500
#
# Epoch 00113: val_loss did not improve from 0.63059
# Epoch 114/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3923 - categorical_accuracy: 1.0000 - val_loss: 0.8928 - val_categorical_accuracy: 0.2500
#
# Epoch 00114: val_loss did not improve from 0.63059
# Epoch 115/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3891 - categorical_accuracy: 1.0000 - val_loss: 0.8705 - val_categorical_accuracy: 0.2500
#
# Epoch 00115: val_loss did not improve from 0.63059
# Epoch 116/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3967 - categorical_accuracy: 0.9524 - val_loss: 1.0351 - val_categorical_accuracy: 0.2500
#
# Epoch 00116: val_loss did not improve from 0.63059
# Epoch 117/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3766 - categorical_accuracy: 1.0000 - val_loss: 0.8358 - val_categorical_accuracy: 0.2500
#
# Epoch 00117: val_loss did not improve from 0.63059
# Epoch 118/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3879 - categorical_accuracy: 1.0000 - val_loss: 0.6710 - val_categorical_accuracy: 0.5000
#
# Epoch 00118: val_loss did not improve from 0.63059
# Epoch 119/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3735 - categorical_accuracy: 1.0000 - val_loss: 0.8194 - val_categorical_accuracy: 0.5000
#
# Epoch 00119: val_loss did not improve from 0.63059
# Epoch 120/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3766 - categorical_accuracy: 1.0000 - val_loss: 0.7620 - val_categorical_accuracy: 0.5000
#
# Epoch 00120: val_loss did not improve from 0.63059
# Epoch 121/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4251 - categorical_accuracy: 1.0000 - val_loss: 0.8487 - val_categorical_accuracy: 0.7500
#
# Epoch 00121: val_loss did not improve from 0.63059
# Epoch 122/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3958 - categorical_accuracy: 1.0000 - val_loss: 0.7866 - val_categorical_accuracy: 0.5000
#
# Epoch 00122: val_loss did not improve from 0.63059
# Epoch 123/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3972 - categorical_accuracy: 1.0000 - val_loss: 0.8922 - val_categorical_accuracy: 0.5000
#
# Epoch 00123: val_loss did not improve from 0.63059
# Epoch 124/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3981 - categorical_accuracy: 1.0000 - val_loss: 0.7634 - val_categorical_accuracy: 0.7500
#
# Epoch 00124: val_loss did not improve from 0.63059
# Epoch 125/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4060 - categorical_accuracy: 1.0000 - val_loss: 1.0911 - val_categorical_accuracy: 0.5000
#
# Epoch 00125: val_loss did not improve from 0.63059
# Epoch 126/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3652 - categorical_accuracy: 1.0000 - val_loss: 1.0302 - val_categorical_accuracy: 0.5000
#
# Epoch 00126: val_loss did not improve from 0.63059
# Epoch 127/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4039 - categorical_accuracy: 1.0000 - val_loss: 0.9591 - val_categorical_accuracy: 0.2500
#
# Epoch 00127: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
#
# Epoch 00127: val_loss did not improve from 0.63059
# Epoch 128/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4085 - categorical_accuracy: 1.0000 - val_loss: 0.8768 - val_categorical_accuracy: 0.5000
#
# Epoch 00128: val_loss did not improve from 0.63059
# Epoch 129/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4302 - categorical_accuracy: 1.0000 - val_loss: 0.9388 - val_categorical_accuracy: 0.2500
#
# Epoch 00129: val_loss did not improve from 0.63059
# Epoch 130/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3916 - categorical_accuracy: 1.0000 - val_loss: 0.9982 - val_categorical_accuracy: 0.2500
#
# Epoch 00130: val_loss did not improve from 0.63059
# Epoch 131/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3711 - categorical_accuracy: 1.0000 - val_loss: 1.0091 - val_categorical_accuracy: 0.5000
#
# Epoch 00131: val_loss did not improve from 0.63059
# Epoch 132/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3733 - categorical_accuracy: 1.0000 - val_loss: 0.7498 - val_categorical_accuracy: 0.5000
#
# Epoch 00132: val_loss did not improve from 0.63059
# Epoch 133/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3626 - categorical_accuracy: 1.0000 - val_loss: 0.8903 - val_categorical_accuracy: 0.2500
#
# Epoch 00133: val_loss did not improve from 0.63059
# Epoch 134/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3798 - categorical_accuracy: 1.0000 - val_loss: 0.7646 - val_categorical_accuracy: 0.5000
#
# Epoch 00134: val_loss did not improve from 0.63059
# Epoch 135/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3980 - categorical_accuracy: 1.0000 - val_loss: 0.9472 - val_categorical_accuracy: 0.5000
#
# Epoch 00135: val_loss did not improve from 0.63059
# Epoch 136/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4113 - categorical_accuracy: 0.9524 - val_loss: 0.9831 - val_categorical_accuracy: 0.2500
#
# Epoch 00136: val_loss did not improve from 0.63059
# Epoch 137/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4038 - categorical_accuracy: 1.0000 - val_loss: 0.9638 - val_categorical_accuracy: 0.5000
#
# Epoch 00137: val_loss did not improve from 0.63059
# Epoch 138/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3617 - categorical_accuracy: 1.0000 - val_loss: 1.0160 - val_categorical_accuracy: 0.5000
#
# Epoch 00138: val_loss did not improve from 0.63059
# Epoch 139/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3805 - categorical_accuracy: 1.0000 - val_loss: 0.6819 - val_categorical_accuracy: 0.5000
#
# Epoch 00139: val_loss did not improve from 0.63059
# Epoch 140/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3664 - categorical_accuracy: 1.0000 - val_loss: 0.9322 - val_categorical_accuracy: 0.5000
#
# Epoch 00140: val_loss did not improve from 0.63059
# Epoch 141/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4250 - categorical_accuracy: 1.0000 - val_loss: 0.9688 - val_categorical_accuracy: 0.5000
#
# Epoch 00141: val_loss did not improve from 0.63059
# Epoch 142/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3496 - categorical_accuracy: 1.0000 - val_loss: 0.7938 - val_categorical_accuracy: 0.5000
#
# Epoch 00142: val_loss did not improve from 0.63059
# Epoch 143/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4017 - categorical_accuracy: 1.0000 - val_loss: 0.8458 - val_categorical_accuracy: 0.5000
#
# Epoch 00143: val_loss did not improve from 0.63059
# Epoch 144/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4263 - categorical_accuracy: 1.0000 - val_loss: 0.7401 - val_categorical_accuracy: 0.5000
#
# Epoch 00144: val_loss did not improve from 0.63059
# Epoch 145/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3722 - categorical_accuracy: 1.0000 - val_loss: 0.9131 - val_categorical_accuracy: 0.5000
#
# Epoch 00145: val_loss did not improve from 0.63059
# Epoch 146/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3848 - categorical_accuracy: 1.0000 - val_loss: 0.7730 - val_categorical_accuracy: 0.5000
#
# Epoch 00146: val_loss did not improve from 0.63059
# Epoch 147/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3924 - categorical_accuracy: 1.0000 - val_loss: 0.8394 - val_categorical_accuracy: 0.5000
#
# Epoch 00147: val_loss did not improve from 0.63059
# Epoch 148/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3783 - categorical_accuracy: 1.0000 - val_loss: 1.0672 - val_categorical_accuracy: 0.5000
#
# Epoch 00148: val_loss did not improve from 0.63059
# Epoch 149/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3664 - categorical_accuracy: 1.0000 - val_loss: 0.8396 - val_categorical_accuracy: 0.5000
#
# Epoch 00149: val_loss did not improve from 0.63059
# Epoch 150/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3661 - categorical_accuracy: 1.0000 - val_loss: 0.7997 - val_categorical_accuracy: 0.5000
#
# Epoch 00150: val_loss did not improve from 0.63059
# Epoch 151/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3552 - categorical_accuracy: 1.0000 - val_loss: 0.8513 - val_categorical_accuracy: 0.5000
#
# Epoch 00151: val_loss did not improve from 0.63059
# Epoch 152/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3566 - categorical_accuracy: 1.0000 - val_loss: 0.8062 - val_categorical_accuracy: 0.5000
#
# Epoch 00152: val_loss did not improve from 0.63059
# Epoch 153/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4075 - categorical_accuracy: 1.0000 - val_loss: 0.7913 - val_categorical_accuracy: 0.5000
#
# Epoch 00153: val_loss did not improve from 0.63059
# Epoch 154/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4144 - categorical_accuracy: 1.0000 - val_loss: 0.9081 - val_categorical_accuracy: 0.5000
#
# Epoch 00154: val_loss did not improve from 0.63059
# Epoch 155/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3636 - categorical_accuracy: 1.0000 - val_loss: 0.7786 - val_categorical_accuracy: 0.5000
#
# Epoch 00155: val_loss did not improve from 0.63059
# Epoch 156/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3830 - categorical_accuracy: 1.0000 - val_loss: 0.8276 - val_categorical_accuracy: 0.5000
#
# Epoch 00156: val_loss did not improve from 0.63059
# Epoch 157/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4165 - categorical_accuracy: 0.9524 - val_loss: 0.7539 - val_categorical_accuracy: 0.5000
#
# Epoch 00157: val_loss did not improve from 0.63059
# Epoch 158/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4026 - categorical_accuracy: 0.9524 - val_loss: 0.8840 - val_categorical_accuracy: 0.5000
#
# Epoch 00158: val_loss did not improve from 0.63059
# Epoch 159/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3530 - categorical_accuracy: 1.0000 - val_loss: 0.9459 - val_categorical_accuracy: 0.5000
#
# Epoch 00159: val_loss did not improve from 0.63059
# Epoch 160/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3932 - categorical_accuracy: 1.0000 - val_loss: 0.7263 - val_categorical_accuracy: 0.5000
#
# Epoch 00160: val_loss did not improve from 0.63059
# Epoch 161/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4044 - categorical_accuracy: 1.0000 - val_loss: 0.8494 - val_categorical_accuracy: 0.5000
#
# Epoch 00161: val_loss did not improve from 0.63059
# Epoch 162/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4197 - categorical_accuracy: 1.0000 - val_loss: 0.8742 - val_categorical_accuracy: 0.5000
#
# Epoch 00162: val_loss did not improve from 0.63059
# Epoch 163/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3703 - categorical_accuracy: 1.0000 - val_loss: 0.8671 - val_categorical_accuracy: 0.5000
#
# Epoch 00163: val_loss did not improve from 0.63059
# Epoch 164/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3731 - categorical_accuracy: 1.0000 - val_loss: 0.7555 - val_categorical_accuracy: 0.5000
#
# Epoch 00164: val_loss did not improve from 0.63059
# Epoch 165/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3785 - categorical_accuracy: 1.0000 - val_loss: 0.9000 - val_categorical_accuracy: 0.5000
#
# Epoch 00165: val_loss did not improve from 0.63059
# Epoch 166/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3595 - categorical_accuracy: 1.0000 - val_loss: 0.9200 - val_categorical_accuracy: 0.5000
#
# Epoch 00166: val_loss did not improve from 0.63059
# Epoch 167/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3943 - categorical_accuracy: 1.0000 - val_loss: 0.9977 - val_categorical_accuracy: 0.5000
#
# Epoch 00167: val_loss did not improve from 0.63059
# Epoch 168/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3646 - categorical_accuracy: 1.0000 - val_loss: 0.9076 - val_categorical_accuracy: 0.5000
#
# Epoch 00168: val_loss did not improve from 0.63059
# Epoch 169/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3799 - categorical_accuracy: 1.0000 - val_loss: 0.7554 - val_categorical_accuracy: 0.5000
#
# Epoch 00169: val_loss did not improve from 0.63059
# Epoch 170/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3637 - categorical_accuracy: 1.0000 - val_loss: 0.8535 - val_categorical_accuracy: 0.5000
#
# Epoch 00170: val_loss did not improve from 0.63059
# Epoch 171/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3894 - categorical_accuracy: 1.0000 - val_loss: 0.8041 - val_categorical_accuracy: 0.5000
#
# Epoch 00171: val_loss did not improve from 0.63059
# Epoch 172/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3711 - categorical_accuracy: 1.0000 - val_loss: 0.8713 - val_categorical_accuracy: 0.5000
#
# Epoch 00172: ReduceLROnPlateau reducing learning rate to 9.999999310821295e-05.
#
# Epoch 00172: val_loss did not improve from 0.63059
# Epoch 173/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3660 - categorical_accuracy: 1.0000 - val_loss: 0.9545 - val_categorical_accuracy: 0.5000
#
# Epoch 00173: val_loss did not improve from 0.63059
# Epoch 174/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4159 - categorical_accuracy: 1.0000 - val_loss: 0.9677 - val_categorical_accuracy: 0.5000
#
# Epoch 00174: val_loss did not improve from 0.63059
# Epoch 175/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3872 - categorical_accuracy: 1.0000 - val_loss: 0.8503 - val_categorical_accuracy: 0.5000
#
# Epoch 00175: val_loss did not improve from 0.63059
# Epoch 176/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4002 - categorical_accuracy: 1.0000 - val_loss: 0.9532 - val_categorical_accuracy: 0.5000
#
# Epoch 00176: val_loss did not improve from 0.63059
# Epoch 177/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3818 - categorical_accuracy: 1.0000 - val_loss: 0.8168 - val_categorical_accuracy: 0.5000
#
# Epoch 00177: val_loss did not improve from 0.63059
# Epoch 178/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4017 - categorical_accuracy: 1.0000 - val_loss: 0.8055 - val_categorical_accuracy: 0.5000
#
# Epoch 00178: val_loss did not improve from 0.63059
# Epoch 179/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4184 - categorical_accuracy: 1.0000 - val_loss: 0.8261 - val_categorical_accuracy: 0.5000
#
# Epoch 00179: val_loss did not improve from 0.63059
# Epoch 180/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3541 - categorical_accuracy: 1.0000 - val_loss: 0.7621 - val_categorical_accuracy: 0.5000
#
# Epoch 00180: val_loss did not improve from 0.63059
# Epoch 181/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3794 - categorical_accuracy: 1.0000 - val_loss: 0.8090 - val_categorical_accuracy: 0.5000
#
# Epoch 00181: val_loss did not improve from 0.63059
# Epoch 182/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3513 - categorical_accuracy: 1.0000 - val_loss: 1.1143 - val_categorical_accuracy: 0.5000
#
# Epoch 00182: val_loss did not improve from 0.63059
# Epoch 183/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3903 - categorical_accuracy: 1.0000 - val_loss: 0.9723 - val_categorical_accuracy: 0.5000
#
# Epoch 00183: val_loss did not improve from 0.63059
# Epoch 184/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3835 - categorical_accuracy: 1.0000 - val_loss: 0.7294 - val_categorical_accuracy: 0.5000
#
# Epoch 00184: val_loss did not improve from 0.63059
# Epoch 185/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3939 - categorical_accuracy: 1.0000 - val_loss: 0.6862 - val_categorical_accuracy: 0.5000
#
# Epoch 00185: val_loss did not improve from 0.63059
# Epoch 186/250
# 1/1 [==============================] - 8s 8s/step - loss: 0.3641 - categorical_accuracy: 1.0000 - val_loss: 0.8648 - val_categorical_accuracy: 0.5000
#
# Epoch 00186: val_loss did not improve from 0.63059
# Epoch 187/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4256 - categorical_accuracy: 1.0000 - val_loss: 0.8934 - val_categorical_accuracy: 0.5000
#
# Epoch 00187: val_loss did not improve from 0.63059
# Epoch 188/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3685 - categorical_accuracy: 1.0000 - val_loss: 0.8631 - val_categorical_accuracy: 0.5000
#
# Epoch 00188: val_loss did not improve from 0.63059
# Epoch 189/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3432 - categorical_accuracy: 1.0000 - val_loss: 0.7767 - val_categorical_accuracy: 0.5000
#
# Epoch 00189: val_loss did not improve from 0.63059
# Epoch 190/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3525 - categorical_accuracy: 1.0000 - val_loss: 0.7888 - val_categorical_accuracy: 0.5000
#
# Epoch 00190: val_loss did not improve from 0.63059
# Epoch 191/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3771 - categorical_accuracy: 1.0000 - val_loss: 0.8625 - val_categorical_accuracy: 0.5000
#
# Epoch 00191: val_loss did not improve from 0.63059
# Epoch 192/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3827 - categorical_accuracy: 1.0000 - val_loss: 0.9372 - val_categorical_accuracy: 0.5000
#
# Epoch 00192: val_loss did not improve from 0.63059
# Epoch 193/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3984 - categorical_accuracy: 1.0000 - val_loss: 0.9971 - val_categorical_accuracy: 0.5000
#
# Epoch 00193: val_loss did not improve from 0.63059
# Epoch 194/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3628 - categorical_accuracy: 1.0000 - val_loss: 0.7480 - val_categorical_accuracy: 0.5000
#
# Epoch 00194: val_loss did not improve from 0.63059
# Epoch 195/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3602 - categorical_accuracy: 1.0000 - val_loss: 0.7684 - val_categorical_accuracy: 0.5000
#
# Epoch 00195: val_loss did not improve from 0.63059
# Epoch 196/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3633 - categorical_accuracy: 1.0000 - val_loss: 0.8514 - val_categorical_accuracy: 0.5000
#
# Epoch 00196: val_loss did not improve from 0.63059
# Epoch 197/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4281 - categorical_accuracy: 1.0000 - val_loss: 1.0924 - val_categorical_accuracy: 0.5000
#
# Epoch 00197: val_loss did not improve from 0.63059
# Epoch 198/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3746 - categorical_accuracy: 1.0000 - val_loss: 0.8791 - val_categorical_accuracy: 0.5000
#
# Epoch 00198: val_loss did not improve from 0.63059
# Epoch 199/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3631 - categorical_accuracy: 1.0000 - val_loss: 0.9879 - val_categorical_accuracy: 0.5000
#
# Epoch 00199: val_loss did not improve from 0.63059
# Epoch 200/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3787 - categorical_accuracy: 1.0000 - val_loss: 0.7704 - val_categorical_accuracy: 0.5000
#
# Epoch 00200: val_loss did not improve from 0.63059
# Epoch 201/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3708 - categorical_accuracy: 1.0000 - val_loss: 0.8560 - val_categorical_accuracy: 0.5000
#
# Epoch 00201: val_loss did not improve from 0.63059
# Epoch 202/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3478 - categorical_accuracy: 1.0000 - val_loss: 0.8068 - val_categorical_accuracy: 0.5000
#
# Epoch 00202: val_loss did not improve from 0.63059
# Epoch 203/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3770 - categorical_accuracy: 1.0000 - val_loss: 0.7293 - val_categorical_accuracy: 0.5000
#
# Epoch 00203: val_loss did not improve from 0.63059
# Epoch 204/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3872 - categorical_accuracy: 1.0000 - val_loss: 0.8917 - val_categorical_accuracy: 0.5000
#
# Epoch 00204: val_loss did not improve from 0.63059
# Epoch 205/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3964 - categorical_accuracy: 1.0000 - val_loss: 0.8806 - val_categorical_accuracy: 0.5000
#
# Epoch 00205: val_loss did not improve from 0.63059
# Epoch 206/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3659 - categorical_accuracy: 1.0000 - val_loss: 0.9392 - val_categorical_accuracy: 0.5000
#
# Epoch 00206: val_loss did not improve from 0.63059
# Epoch 207/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3615 - categorical_accuracy: 1.0000 - val_loss: 0.8055 - val_categorical_accuracy: 0.5000
#
# Epoch 00207: val_loss did not improve from 0.63059
# Epoch 208/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3912 - categorical_accuracy: 1.0000 - val_loss: 0.8437 - val_categorical_accuracy: 0.5000
#
# Epoch 00208: val_loss did not improve from 0.63059
# Epoch 209/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3839 - categorical_accuracy: 1.0000 - val_loss: 0.9061 - val_categorical_accuracy: 0.5000
#
# Epoch 00209: val_loss did not improve from 0.63059
# Epoch 210/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3927 - categorical_accuracy: 1.0000 - val_loss: 0.8136 - val_categorical_accuracy: 0.5000
#
# Epoch 00210: val_loss did not improve from 0.63059
# Epoch 211/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3879 - categorical_accuracy: 1.0000 - val_loss: 0.9053 - val_categorical_accuracy: 0.5000
#
# Epoch 00211: val_loss did not improve from 0.63059
# Epoch 212/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4056 - categorical_accuracy: 0.9524 - val_loss: 0.9310 - val_categorical_accuracy: 0.5000
#
# Epoch 00212: val_loss did not improve from 0.63059
# Epoch 213/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4462 - categorical_accuracy: 0.9524 - val_loss: 0.8087 - val_categorical_accuracy: 0.5000
#
# Epoch 00213: val_loss did not improve from 0.63059
# Epoch 214/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3792 - categorical_accuracy: 1.0000 - val_loss: 1.0145 - val_categorical_accuracy: 0.5000
#
# Epoch 00214: val_loss did not improve from 0.63059
# Epoch 215/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3583 - categorical_accuracy: 1.0000 - val_loss: 0.8222 - val_categorical_accuracy: 0.5000
#
# Epoch 00215: val_loss did not improve from 0.63059
# Epoch 216/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4052 - categorical_accuracy: 1.0000 - val_loss: 0.8543 - val_categorical_accuracy: 0.5000
#
# Epoch 00216: val_loss did not improve from 0.63059
# Epoch 217/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3910 - categorical_accuracy: 1.0000 - val_loss: 0.8417 - val_categorical_accuracy: 0.5000
#
# Epoch 00217: ReduceLROnPlateau reducing learning rate to 9.999999019782991e-06.
#
# Epoch 00217: val_loss did not improve from 0.63059
# Epoch 218/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3981 - categorical_accuracy: 1.0000 - val_loss: 0.7583 - val_categorical_accuracy: 0.5000
#
# Epoch 00218: val_loss did not improve from 0.63059
# Epoch 219/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3628 - categorical_accuracy: 1.0000 - val_loss: 1.0788 - val_categorical_accuracy: 0.5000
#
# Epoch 00219: val_loss did not improve from 0.63059
# Epoch 220/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3991 - categorical_accuracy: 1.0000 - val_loss: 0.8900 - val_categorical_accuracy: 0.5000
#
# Epoch 00220: val_loss did not improve from 0.63059
# Epoch 221/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3628 - categorical_accuracy: 1.0000 - val_loss: 0.7163 - val_categorical_accuracy: 0.5000
#
# Epoch 00221: val_loss did not improve from 0.63059
# Epoch 222/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3694 - categorical_accuracy: 1.0000 - val_loss: 0.7712 - val_categorical_accuracy: 0.5000
#
# Epoch 00222: val_loss did not improve from 0.63059
# Epoch 223/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3626 - categorical_accuracy: 1.0000 - val_loss: 0.8983 - val_categorical_accuracy: 0.5000
#
# Epoch 00223: val_loss did not improve from 0.63059
# Epoch 224/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3740 - categorical_accuracy: 1.0000 - val_loss: 1.0042 - val_categorical_accuracy: 0.5000
#
# Epoch 00224: val_loss did not improve from 0.63059
# Epoch 225/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3875 - categorical_accuracy: 1.0000 - val_loss: 0.8877 - val_categorical_accuracy: 0.5000
#
# Epoch 00225: val_loss did not improve from 0.63059
# Epoch 226/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3751 - categorical_accuracy: 1.0000 - val_loss: 0.8637 - val_categorical_accuracy: 0.5000
#
# Epoch 00226: val_loss did not improve from 0.63059
# Epoch 227/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3630 - categorical_accuracy: 1.0000 - val_loss: 0.8531 - val_categorical_accuracy: 0.5000
#
# Epoch 00227: val_loss did not improve from 0.63059
# Epoch 228/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3731 - categorical_accuracy: 1.0000 - val_loss: 0.9925 - val_categorical_accuracy: 0.5000
#
# Epoch 00228: val_loss did not improve from 0.63059
# Epoch 229/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4238 - categorical_accuracy: 1.0000 - val_loss: 0.7951 - val_categorical_accuracy: 0.5000
#
# Epoch 00229: val_loss did not improve from 0.63059
# Epoch 230/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3820 - categorical_accuracy: 1.0000 - val_loss: 1.0245 - val_categorical_accuracy: 0.5000
#
# Epoch 00230: val_loss did not improve from 0.63059
# Epoch 231/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3820 - categorical_accuracy: 1.0000 - val_loss: 0.7916 - val_categorical_accuracy: 0.5000
#
# Epoch 00231: val_loss did not improve from 0.63059
# Epoch 232/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3758 - categorical_accuracy: 1.0000 - val_loss: 0.8245 - val_categorical_accuracy: 0.5000
#
# Epoch 00232: val_loss did not improve from 0.63059
# Epoch 233/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3918 - categorical_accuracy: 1.0000 - val_loss: 0.9261 - val_categorical_accuracy: 0.5000
#
# Epoch 00233: val_loss did not improve from 0.63059
# Epoch 234/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3835 - categorical_accuracy: 1.0000 - val_loss: 0.8808 - val_categorical_accuracy: 0.5000
#
# Epoch 00234: val_loss did not improve from 0.63059
# Epoch 235/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3613 - categorical_accuracy: 1.0000 - val_loss: 0.7986 - val_categorical_accuracy: 0.5000
#
# Epoch 00235: val_loss did not improve from 0.63059
# Epoch 236/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4027 - categorical_accuracy: 0.9524 - val_loss: 0.8293 - val_categorical_accuracy: 0.7500
#
# Epoch 00236: val_loss did not improve from 0.63059
# Epoch 237/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3617 - categorical_accuracy: 1.0000 - val_loss: 0.7445 - val_categorical_accuracy: 0.5000
#
# Epoch 00237: val_loss did not improve from 0.63059
# Epoch 238/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3913 - categorical_accuracy: 1.0000 - val_loss: 0.8393 - val_categorical_accuracy: 0.5000
#
# Epoch 00238: val_loss did not improve from 0.63059
# Epoch 239/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3770 - categorical_accuracy: 1.0000 - val_loss: 0.8642 - val_categorical_accuracy: 0.5000
#
# Epoch 00239: val_loss did not improve from 0.63059
# Epoch 240/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3760 - categorical_accuracy: 1.0000 - val_loss: 0.7697 - val_categorical_accuracy: 0.7500
#
# Epoch 00240: val_loss did not improve from 0.63059
# Epoch 241/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3626 - categorical_accuracy: 1.0000 - val_loss: 0.9908 - val_categorical_accuracy: 0.5000
#
# Epoch 00241: val_loss did not improve from 0.63059
# Epoch 242/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3684 - categorical_accuracy: 1.0000 - val_loss: 0.8239 - val_categorical_accuracy: 0.7500
#
# Epoch 00242: val_loss did not improve from 0.63059
# Epoch 243/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3804 - categorical_accuracy: 1.0000 - val_loss: 1.0057 - val_categorical_accuracy: 0.5000
#
# Epoch 00243: val_loss did not improve from 0.63059
# Epoch 244/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3896 - categorical_accuracy: 1.0000 - val_loss: 0.8230 - val_categorical_accuracy: 0.5000
#
# Epoch 00244: val_loss did not improve from 0.63059
# Epoch 245/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3598 - categorical_accuracy: 1.0000 - val_loss: 0.7560 - val_categorical_accuracy: 0.5000
#
# Epoch 00245: val_loss did not improve from 0.63059
# Epoch 246/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3708 - categorical_accuracy: 1.0000 - val_loss: 0.7894 - val_categorical_accuracy: 0.5000
#
# Epoch 00246: val_loss did not improve from 0.63059
# Epoch 247/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3977 - categorical_accuracy: 1.0000 - val_loss: 0.9403 - val_categorical_accuracy: 0.5000
#
# Epoch 00247: val_loss did not improve from 0.63059
# Epoch 248/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3709 - categorical_accuracy: 1.0000 - val_loss: 0.8947 - val_categorical_accuracy: 0.5000
#
# Epoch 00248: val_loss did not improve from 0.63059
# Epoch 249/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.3914 - categorical_accuracy: 1.0000 - val_loss: 0.8398 - val_categorical_accuracy: 0.7500
#
# Epoch 00249: val_loss did not improve from 0.63059
# Epoch 250/250
# 1/1 [==============================] - 7s 7s/step - loss: 0.4160 - categorical_accuracy: 1.0000 - val_loss: 0.8669 - val_categorical_accuracy: 0.5000
#
# Epoch 00250: val_loss did not improve from 0.63059

# %% [markdown]
# #**Testing**

# %% [markdown]
# ## **Validation generator**

# %%
from sklearn.metrics import confusion_matrix, plot_confusion_matrix
from keras.models import load_model
loaded_model = buildModelFromDisk('./checkpoint.h5')


y_pred = loaded_model.predict_generator(validation_generator)
y_pred_argmax = [i.argmax() for i in y_pred]
y_true = validation_generator.classes

cm = confusion_matrix(y_true, y_pred_argmax)

print (cm)

total = sum(sum(cm))
hits = 0
for i in range(0,2):
  hits += cm[i][i]

print (hits / total)


plt.imshow(cm, cmap=plt.cm.Blues)
plt.xlabel("Predicted labels")
plt.ylabel("True labels")
plt.xticks([], [])
plt.yticks([], [])
plt.title('Confusion matrix ')
plt.colorbar()
plt.show()
# Out:
# [[2 0]
#  [1 1]]
# 0.75

# %% [markdown]
# ##**/tests folder**

# %%
# SNIPPET TO LOAD DATA FROM DIRECTORY, FOR MANUAL WORK WITHOUT GENERATORS

import cv2
import glob
import numpy as np
import matplotlib.pyplot as plt
from keras.preprocessing import image

x_data = []
files = glob.glob (TEST_DIR + '/*.jpg') 

fig=plt.figure(figsize=(32, 32))
plotted_images = 1 

loaded_model = buildModelFromDisk('./checkpoint.h5')
predictions = []

for image_source in files:
    (image_original, image_tensor) = buildSampleFromDisk(image_source)

    fig.add_subplot(1, len(files), plotted_images) # subplot(rows, colums, currentIndexToPlot)
    plotted_images +=1
    
    image_label = image_source.split('/')[-1]
    plt.imshow(image_original)
    plt.xlabel(image_label)


    prediction = loaded_model.predict(image_tensor)
    print('prediction for ' + str(image_source))
    print(prediction)
    
    pred_label = prediction.argmax()

    if(pred_label == 0):
      print('calcium def')
    else:
      print('iron def')
# Out:
# prediction for /content/drive/My Drive/CAI/iron_calcium/tests/cal2.jpg
# [[0.5903237  0.40967634]]
# calcium def
# prediction for /content/drive/My Drive/CAI/iron_calcium/tests/iron1.jpg
# [[0.14393695 0.85606307]]
# iron def
# prediction for /content/drive/My Drive/CAI/iron_calcium/tests/iron2.jpg
# [[0.01661911 0.9833809 ]]
# iron def
# prediction for /content/drive/My Drive/CAI/iron_calcium/tests/iron3.jpg
# [[0.21647727 0.7835228 ]]
# iron def
# prediction for /content/drive/My Drive/CAI/iron_calcium/tests/cal3.jpg
# [[0.1676233 0.8323768]]
# iron def
# prediction for /content/drive/My Drive/CAI/iron_calcium/tests/cal1.jpg
# [[0.64999735 0.35000262]]
# calcium def
